# %% [markdown]
# # Introduction to [Surprise](http://surpriselib.com)

# %% [markdown]
# Before we explore what Surprise has to offer, here's a quick reminder:
#
# Recommender Systems have become ubiquitous in the modern data science landscape, as companies like Google, Netflix, Pandora, and Facebook rely on them to provide targeted content recommendations and create a more enjoyable user experience.  In this lab, we'll focus on the Surprise package.
#
# [Collaborative Filtering](https://en.wikipedia.org/wiki/Collaborative_filtering) relies on a ***ratings matrix*** for all items, to generate similarities between items and users based on similar ratings.
#
# [Content-Based Filtering](https://en.wikipedia.org/wiki/Recommender_system#Content-based_filtering) explicitly maps items and/or users into a shared feature space based on explicit user/item characteristics. State of the art recommenders will often rely on hybrid approaches, so seek understand the differences, strengths, and weaknesses of each approach.

# %%
# Install via conda:

# !conda install scikit-surprise -y

# alternatively try

# !conda install -c conda-forge scikit-surprise

# %%
import pandas as pd
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate, train_test_split
from surprise import accuracy

# %%
from surprise import SlopeOne

# %% [markdown]
# We'll be looking at a [jokes dataset called Jester](http://eigentaste.berkeley.edu/dataset/). This is fortunately built-in to Surprise and can be downloaded on the backend.

# %%
# Load the Jester dataset (download if needed)
# data = Dataset.load_builtin('jester')
data = Dataset.load_builtin('ml-100k')

# %% [markdown]
# > Look for the prompt above to download the dataset to a hidden location. Remember to delete if you need the storage space!

# %%
# We'll use the famous SVD algorithm.
algo = SVD(verbose=True)

# you can also build KNNBasic and other types of models

# Run 5-fold cross-validation and print results
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, n_jobs=-1, verbose=True)

# ml-100k dataset: this takes around .5 minute
# jester dataset: this takes around 10 minutes
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9374  0.9410  0.9386  0.9305  0.9344  0.9364  0.0036
# MAE (testset)     0.7384  0.7408  0.7405  0.7351  0.7365  0.7383  0.0022
# Fit time          4.03    4.12    4.24    4.22    4.17    4.16    0.07
# Test time         0.15    0.14    0.14    0.14    0.14    0.14    0.00
# {'test_rmse': array([0.93735398, 0.94097543, 0.93855725, 0.93053843, 0.93440996]),
#  'test_mae': array([0.73840022, 0.74083692, 0.74053892, 0.7351447 , 0.7365145 ]),
#  'fit_time': (4.033485174179077,
#   4.124841928482056,
#   4.24336576461792,
#   4.221968173980713,
#   4.168344020843506),
#  'test_time': (0.14960384368896484,
#   0.1428830623626709,
#   0.14039087295532227,
#   0.13979482650756836,
#   0.14437580108642578)}

# %%
# let's do train-test-split, where test set is 25% of the ratings
trainset, testset = train_test_split(data, test_size=.25)

# Train the algorithm on the trainset, and predict ratings for the testset
algo.fit(trainset)
predictions = algo.test(testset)

# you can also use this one-liner: `predictions = algo.fit(trainset).test(testset)`
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19

# %%
predictions
# Out:
# [Prediction(uid='559', iid='191', r_ui=5.0, est=3.5713959726377444, details={'was_impossible': False}),
#  Prediction(uid='80', iid='194', r_ui=3.0, est=4.095569354891457, details={'was_impossible': False}),
#  Prediction(uid='130', iid='158', r_ui=5.0, est=3.584446707410145, details={'was_impossible': False}),
#  Prediction(uid='533', iid='193', r_ui=4.0, est=3.5276320561740775, details={'was_impossible': False}),
#  Prediction(uid='712', iid='969', r_ui=4.0, est=3.7419628731201042, details={'was_impossible': False}),
#  Prediction(uid='524', iid='237', r_ui=3.0, est=3.2434827981630714, details={'was_impossible': False}),
#  Prediction(uid='269', iid='197', r_ui=5.0, est=4.416375103356922, details={'was_impossible': False}),
#  Prediction(uid='60', iid='617', r_ui=4.0, est=3.9442344085579717, details={'was_impossible': False}),
#  Prediction(uid='40', iid='243', r_ui=2.0, est=1.8970164451573233, details={'was_impossible': False}),
#  Prediction(uid='462', iid='292', r_ui=5.0, est=3.976013075765163, details={'was_impossible': False}),
#  Prediction(uid='476', iid='211', r_ui=5.0, est=3.835456242235416, details={'was_impossible': False}),
#  Prediction(uid='322', iid='157', r_ui=5.0, est=3.972602991834913, details={'was_impossible': False}),
#  Prediction(uid='398', iid='284', r_ui=2.0, est=3.3129386530728393, details={'was_impossible': False}),
#  Prediction(uid='841', iid='888', r_ui=5.0, est=4.048304413166509, details={'was_impossible': False}),
#  Prediction(uid='782', iid='331', r_ui=3.0, est=2.964296583710536, details={'was_impossible': False}),
#  Prediction(uid='347', iid='1016', r_ui=3.0, est=3.3808378256232574, details={'was_impossible': False}),
#  Prediction(uid='660', iid='748', r_ui=3.0, est=2.312854381512519, details={'was_impossible': False}),
#  Prediction(uid='788', iid='739', r_ui=2.0, est=3.2556733408386322, details={'was_impossible': False}),
#  Prediction(uid='532', iid='1496', r_ui=2.0, est=3.8643407083467376, details={'was_impossible': False}),
#  Prediction(uid='206', iid='242', r_ui=3.0, est=2.6462787146011055, details={'was_impossible': False}),
#  Prediction(uid='854', iid='499', r_ui=4.0, est=3.5477057997628605, details={'was_impossible': False}),
#  Prediction(uid='327', iid='651', r_ui=4.0, est=3.648007319947228, details={'was_impossible': False}),
#  Prediction(uid='75', iid='100', r_ui=5.0, est=4.115736788458084, details={'was_impossible': False}),
#  Prediction(uid='814', iid='559', r_ui=3.0, est=2.9319659099964843, details={'was_impossible': False}),
#  Prediction(uid='210', iid='420', r_ui=4.0, est=4.1981817139518816, details={'was_impossible': False}),
#  Prediction(uid='425', iid='219', r_ui=2.0, est=2.7753855020171336, details={'was_impossible': False}),
#  Prediction(uid='357', iid='456', r_ui=3.0, est=3.111018084289766, details={'was_impossible': False}),
#  Prediction(uid='659', iid='86', r_ui=5.0, est=3.6031775428117077, details={'was_impossible': False}),
#  Prediction(uid='918', iid='1200', r_ui=4.0, est=2.9480053927215035, details={'was_impossible': False}),
#  Prediction(uid='409', iid='156', r_ui=2.0, est=4.214796842418232, details={'was_impossible': False}),
#  Prediction(uid='5', iid='151', r_ui=3.0, est=3.3062604024245763, details={'was_impossible': False}),
#  Prediction(uid='450', iid='1037', r_ui=2.0, est=2.884608850632685, details={'was_impossible': False}),
#  Prediction(uid='624', iid='255', r_ui=3.0, est=3.5731594836233582, details={'was_impossible': False}),
#  Prediction(uid='846', iid='700', r_ui=2.0, est=3.1152032129359575, details={'was_impossible': False}),
#  Prediction(uid='343', iid='385', r_ui=3.0, est=4.0208045199787446, details={'was_impossible': False}),
#  Prediction(uid='259', iid='121', r_ui=3.0, est=3.4031918477740857, details={'was_impossible': False}),
#  Prediction(uid='505', iid='11', r_ui=4.0, est=3.1041525886877883, details={'was_impossible': False}),
#  Prediction(uid='880', iid='148', r_ui=2.0, est=2.9367241394945864, details={'was_impossible': False}),
#  Prediction(uid='664', iid='92', r_ui=4.0, est=3.4539003618791146, details={'was_impossible': False}),
#  Prediction(uid='773', iid='475', r_ui=3.0, est=4.052209638896924, details={'was_impossible': False}),
#  Prediction(uid='715', iid='159', r_ui=3.0, est=3.080187607741272, details={'was_impossible': False}),
#  Prediction(uid='868', iid='382', r_ui=4.0, est=2.9184023964147894, details={'was_impossible': False}),
#  Prediction(uid='933', iid='229', r_ui=1.0, est=1.8257756559152363, details={'was_impossible': False}),
#  Prediction(uid='684', iid='225', r_ui=3.0, est=2.978888247458798, details={'was_impossible': False}),
#  Prediction(uid='159', iid='1023', r_ui=2.0, est=2.7991556695847133, details={'was_impossible': False}),
#  Prediction(uid='25', iid='222', r_ui=4.0, est=4.160076135438647, details={'was_impossible': False}),
#  Prediction(uid='881', iid='216', r_ui=4.0, est=3.7701713754329194, details={'was_impossible': False}),
#  Prediction(uid='94', iid='432', r_ui=4.0, est=4.19386935825378, details={'was_impossible': False}),
#  Prediction(uid='613', iid='272', r_ui=5.0, est=4.388313103288602, details={'was_impossible': False}),
#  Prediction(uid='748', iid='175', r_ui=5.0, est=3.3480696228732882, details={'was_impossible': False}),
#  Prediction(uid='655', iid='651', r_ui=4.0, est=3.3234073550197065, details={'was_impossible': False}),
#  Prediction(uid='606', iid='183', r_ui=5.0, est=4.273753479093971, details={'was_impossible': False}),
#  Prediction(uid='848', iid='582', r_ui=4.0, est=4.3456563634845935, details={'was_impossible': False}),
#  Prediction(uid='95', iid='1188', r_ui=2.0, est=2.9844154563922816, details={'was_impossible': False}),
#  Prediction(uid='373', iid='431', r_ui=5.0, est=3.5681601464691846, details={'was_impossible': False}),
#  Prediction(uid='711', iid='240', r_ui=1.0, est=3.3343552359348174, details={'was_impossible': False}),
#  Prediction(uid='608', iid='275', r_ui=5.0, est=4.0005567736928676, details={'was_impossible': False}),
#  Prediction(uid='826', iid='228', r_ui=3.0, est=3.999376347363979, details={'was_impossible': False}),
#  Prediction(uid='42', iid='1051', r_ui=4.0, est=3.266338577866591, details={'was_impossible': False}),
#  Prediction(uid='186', iid='302', r_ui=3.0, est=4.0520864281287645, details={'was_impossible': False}),
#  Prediction(uid='707', iid='525', r_ui=3.0, est=3.802985012251565, details={'was_impossible': False}),
#  Prediction(uid='809', iid='748', r_ui=3.0, est=3.07474916471971, details={'was_impossible': False}),
#  Prediction(uid='269', iid='51', r_ui=2.0, est=2.9241895427792297, details={'was_impossible': False}),
#  Prediction(uid='653', iid='573', r_ui=1.0, est=2.267967266708412, details={'was_impossible': False}),
#  Prediction(uid='318', iid='265', r_ui=4.0, est=3.872749278399094, details={'was_impossible': False}),
#  Prediction(uid='296', iid='544', r_ui=4.0, est=3.8774525971717018, details={'was_impossible': False}),
#  Prediction(uid='650', iid='393', r_ui=3.0, est=2.989437072177848, details={'was_impossible': False}),
#  Prediction(uid='422', iid='117', r_ui=2.0, est=3.8429341994271335, details={'was_impossible': False}),
#  Prediction(uid='483', iid='676', r_ui=4.0, est=3.024205489775552, details={'was_impossible': False}),
#  Prediction(uid='599', iid='278', r_ui=3.0, est=3.5095674766581544, details={'was_impossible': False}),
#  Prediction(uid='288', iid='544', r_ui=5.0, est=3.089182709005506, details={'was_impossible': False}),
#  Prediction(uid='450', iid='905', r_ui=5.0, est=3.3231126414364267, details={'was_impossible': False}),
#  Prediction(uid='445', iid='183', r_ui=2.0, est=2.5163765296386154, details={'was_impossible': False}),
#  Prediction(uid='451', iid='359', r_ui=2.0, est=3.2625105877003726, details={'was_impossible': False}),
#  Prediction(uid='782', iid='1666', r_ui=2.0, est=2.938366365278483, details={'was_impossible': False}),
#  Prediction(uid='399', iid='2', r_ui=3.0, est=2.9779110492018934, details={'was_impossible': False}),
#  Prediction(uid='903', iid='1142', r_ui=5.0, est=3.996002707529887, details={'was_impossible': False}),
#  Prediction(uid='454', iid='258', r_ui=4.0, est=3.089763507665894, details={'was_impossible': False}),
#  Prediction(uid='1', iid='108', r_ui=5.0, est=2.942159320816392, details={'was_impossible': False}),
#  Prediction(uid='773', iid='152', r_ui=5.0, est=3.458617550538782, details={'was_impossible': False}),
#  Prediction(uid='882', iid='66', r_ui=4.0, est=4.268625930566848, details={'was_impossible': False}),
#  Prediction(uid='663', iid='919', r_ui=3.0, est=4.055737553257471, details={'was_impossible': False}),
#  Prediction(uid='114', iid='483', r_ui=4.0, est=4.02908050488811, details={'was_impossible': False}),
#  Prediction(uid='399', iid='679', r_ui=3.0, est=2.7352455556949367, details={'was_impossible': False}),
#  Prediction(uid='846', iid='684', r_ui=5.0, est=3.853101880072974, details={'was_impossible': False}),
#  Prediction(uid='363', iid='384', r_ui=1.0, est=2.7453974817187325, details={'was_impossible': False}),
#  Prediction(uid='32', iid='475', r_ui=5.0, est=3.7996436726995166, details={'was_impossible': False}),
#  Prediction(uid='312', iid='134', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='244', iid='1225', r_ui=2.0, est=3.1052396032600584, details={'was_impossible': False}),
#  Prediction(uid='868', iid='566', r_ui=1.0, est=2.689592524544219, details={'was_impossible': False}),
#  Prediction(uid='234', iid='591', r_ui=3.0, est=2.9999267608984903, details={'was_impossible': False}),
#  Prediction(uid='472', iid='117', r_ui=3.0, est=4.986566500353727, details={'was_impossible': False}),
#  Prediction(uid='733', iid='107', r_ui=4.0, est=2.944416881755905, details={'was_impossible': False}),
#  Prediction(uid='435', iid='675', r_ui=3.0, est=3.535661640887559, details={'was_impossible': False}),
#  Prediction(uid='130', iid='418', r_ui=5.0, est=4.250395214562307, details={'was_impossible': False}),
#  Prediction(uid='868', iid='168', r_ui=3.0, est=3.7675943716180607, details={'was_impossible': False}),
#  Prediction(uid='867', iid='294', r_ui=3.0, est=3.687546639217131, details={'was_impossible': False}),
#  Prediction(uid='450', iid='163', r_ui=4.0, est=3.7356239402682374, details={'was_impossible': False}),
#  Prediction(uid='844', iid='117', r_ui=4.0, est=3.4517041782382947, details={'was_impossible': False}),
#  Prediction(uid='429', iid='128', r_ui=3.0, est=3.695310968858392, details={'was_impossible': False}),
#  Prediction(uid='563', iid='403', r_ui=4.0, est=3.655368554718654, details={'was_impossible': False}),
#  Prediction(uid='643', iid='177', r_ui=4.0, est=4.184262940280208, details={'was_impossible': False}),
#  Prediction(uid='176', iid='875', r_ui=4.0, est=3.1929445077039924, details={'was_impossible': False}),
#  Prediction(uid='387', iid='1187', r_ui=4.0, est=3.349126053067459, details={'was_impossible': False}),
#  Prediction(uid='206', iid='314', r_ui=1.0, est=1.5665671540198793, details={'was_impossible': False}),
#  Prediction(uid='593', iid='174', r_ui=4.0, est=4.208026988243901, details={'was_impossible': False}),
#  Prediction(uid='59', iid='604', r_ui=3.0, est=4.174080585074084, details={'was_impossible': False}),
#  Prediction(uid='629', iid='153', r_ui=5.0, est=4.498943649363356, details={'was_impossible': False}),
#  Prediction(uid='704', iid='22', r_ui=2.0, est=4.069117260471027, details={'was_impossible': False}),
#  Prediction(uid='110', iid='272', r_ui=4.0, est=4.09004322318978, details={'was_impossible': False}),
#  Prediction(uid='748', iid='208', r_ui=4.0, est=3.6272691591600656, details={'was_impossible': False}),
#  Prediction(uid='389', iid='474', r_ui=5.0, est=4.341929072805608, details={'was_impossible': False}),
#  Prediction(uid='659', iid='234', r_ui=4.0, est=3.814602266929716, details={'was_impossible': False}),
#  Prediction(uid='655', iid='1153', r_ui=3.0, est=2.613119932238729, details={'was_impossible': False}),
#  Prediction(uid='42', iid='371', r_ui=4.0, est=3.6731061503471896, details={'was_impossible': False}),
#  Prediction(uid='478', iid='150', r_ui=4.0, est=3.632526783122691, details={'was_impossible': False}),
#  Prediction(uid='551', iid='721', r_ui=5.0, est=3.8133163267079797, details={'was_impossible': False}),
#  Prediction(uid='712', iid='50', r_ui=4.0, est=4.444161826376639, details={'was_impossible': False}),
#  Prediction(uid='556', iid='507', r_ui=5.0, est=4.180476250168978, details={'was_impossible': False}),
#  Prediction(uid='130', iid='622', r_ui=3.0, est=4.079185362914934, details={'was_impossible': False}),
#  Prediction(uid='178', iid='155', r_ui=4.0, est=3.1028542612732193, details={'was_impossible': False}),
#  Prediction(uid='64', iid='72', r_ui=4.0, est=3.062886752259182, details={'was_impossible': False}),
#  Prediction(uid='206', iid='359', r_ui=1.0, est=2.550216480012307, details={'was_impossible': False}),
#  Prediction(uid='488', iid='358', r_ui=3.0, est=2.224582048540339, details={'was_impossible': False}),
#  Prediction(uid='130', iid='888', r_ui=3.0, est=4.2480896745038565, details={'was_impossible': False}),
#  Prediction(uid='250', iid='418', r_ui=5.0, est=3.7022611831272836, details={'was_impossible': False}),
#  Prediction(uid='664', iid='717', r_ui=1.0, est=2.8120922303856464, details={'was_impossible': False}),
#  Prediction(uid='141', iid='15', r_ui=5.0, est=4.140440664313365, details={'was_impossible': False}),
#  Prediction(uid='393', iid='417', r_ui=3.0, est=3.0638695231411037, details={'was_impossible': False}),
#  Prediction(uid='291', iid='706', r_ui=3.0, est=3.7156874181805346, details={'was_impossible': False}),
#  Prediction(uid='443', iid='260', r_ui=1.0, est=2.353023222637328, details={'was_impossible': False}),
#  Prediction(uid='598', iid='22', r_ui=5.0, est=4.219975676019305, details={'was_impossible': False}),
#  Prediction(uid='646', iid='272', r_ui=4.0, est=3.7477282653878268, details={'was_impossible': False}),
#  Prediction(uid='198', iid='131', r_ui=3.0, est=3.2253582759277006, details={'was_impossible': False}),
#  Prediction(uid='3', iid='343', r_ui=3.0, est=3.098115534319682, details={'was_impossible': False}),
#  Prediction(uid='610', iid='1558', r_ui=3.0, est=4.001110956684106, details={'was_impossible': False}),
#  Prediction(uid='342', iid='68', r_ui=3.0, est=3.344584865145377, details={'was_impossible': False}),
#  Prediction(uid='774', iid='1091', r_ui=1.0, est=1.108095090213436, details={'was_impossible': False}),
#  Prediction(uid='869', iid='125', r_ui=3.0, est=3.1754259031084784, details={'was_impossible': False}),
#  Prediction(uid='782', iid='358', r_ui=4.0, est=2.2749080496269722, details={'was_impossible': False}),
#  Prediction(uid='763', iid='151', r_ui=4.0, est=3.6421573779898475, details={'was_impossible': False}),
#  Prediction(uid='880', iid='238', r_ui=4.0, est=4.148927420281636, details={'was_impossible': False}),
#  Prediction(uid='744', iid='428', r_ui=4.0, est=3.6462184107007487, details={'was_impossible': False}),
#  Prediction(uid='620', iid='1091', r_ui=4.0, est=3.351790853029639, details={'was_impossible': False}),
#  Prediction(uid='385', iid='211', r_ui=3.0, est=3.799775015458861, details={'was_impossible': False}),
#  Prediction(uid='379', iid='402', r_ui=3.0, est=3.548058138636874, details={'was_impossible': False}),
#  Prediction(uid='246', iid='423', r_ui=3.0, est=2.850747580787108, details={'was_impossible': False}),
#  Prediction(uid='15', iid='251', r_ui=2.0, est=4.11168805819238, details={'was_impossible': False}),
#  Prediction(uid='648', iid='448', r_ui=3.0, est=3.8648774778952246, details={'was_impossible': False}),
#  Prediction(uid='786', iid='849', r_ui=2.0, est=3.1565544613483154, details={'was_impossible': False}),
#  Prediction(uid='257', iid='121', r_ui=3.0, est=3.6424563407561883, details={'was_impossible': False}),
#  Prediction(uid='379', iid='158', r_ui=1.0, est=2.8301520951679984, details={'was_impossible': False}),
#  Prediction(uid='64', iid='381', r_ui=4.0, est=3.2494574984187965, details={'was_impossible': False}),
#  Prediction(uid='919', iid='535', r_ui=3.0, est=3.0481432478446675, details={'was_impossible': False}),
#  Prediction(uid='918', iid='428', r_ui=5.0, est=3.020259212898658, details={'was_impossible': False}),
#  Prediction(uid='758', iid='526', r_ui=4.0, est=4.327765278973907, details={'was_impossible': False}),
#  Prediction(uid='292', iid='64', r_ui=5.0, est=4.633837265979102, details={'was_impossible': False}),
#  Prediction(uid='846', iid='796', r_ui=1.0, est=2.729307350754696, details={'was_impossible': False}),
#  Prediction(uid='179', iid='905', r_ui=4.0, est=2.7374158790387946, details={'was_impossible': False}),
#  Prediction(uid='752', iid='321', r_ui=3.0, est=2.8457967831973683, details={'was_impossible': False}),
#  Prediction(uid='756', iid='403', r_ui=2.0, est=3.4285101594987464, details={'was_impossible': False}),
#  Prediction(uid='916', iid='81', r_ui=5.0, est=3.3740091821982974, details={'was_impossible': False}),
#  Prediction(uid='537', iid='705', r_ui=3.0, est=3.4351768783385683, details={'was_impossible': False}),
#  Prediction(uid='426', iid='641', r_ui=4.0, est=4.123879025820347, details={'was_impossible': False}),
#  Prediction(uid='650', iid='417', r_ui=3.0, est=2.7663699189480595, details={'was_impossible': False}),
#  Prediction(uid='1', iid='147', r_ui=3.0, est=3.601101165199619, details={'was_impossible': False}),
#  Prediction(uid='850', iid='566', r_ui=5.0, est=4.136111017878048, details={'was_impossible': False}),
#  Prediction(uid='406', iid='1267', r_ui=3.0, est=3.2034604104789337, details={'was_impossible': False}),
#  Prediction(uid='790', iid='85', r_ui=3.0, est=2.754390453965611, details={'was_impossible': False}),
#  Prediction(uid='848', iid='480', r_ui=5.0, est=4.830069418057071, details={'was_impossible': False}),
#  Prediction(uid='268', iid='432', r_ui=3.0, est=3.146135465548628, details={'was_impossible': False}),
#  Prediction(uid='347', iid='22', r_ui=5.0, est=4.726506729853519, details={'was_impossible': False}),
#  Prediction(uid='786', iid='117', r_ui=4.0, est=4.101827888287707, details={'was_impossible': False}),
#  Prediction(uid='712', iid='220', r_ui=5.0, est=3.5472679470655004, details={'was_impossible': False}),
#  Prediction(uid='880', iid='7', r_ui=3.0, est=3.8980037639663516, details={'was_impossible': False}),
#  Prediction(uid='339', iid='159', r_ui=3.0, est=3.7098125995095352, details={'was_impossible': False}),
#  Prediction(uid='406', iid='382', r_ui=5.0, est=3.688529521068047, details={'was_impossible': False}),
#  Prediction(uid='498', iid='77', r_ui=2.0, est=2.7864821262521025, details={'was_impossible': False}),
#  Prediction(uid='222', iid='363', r_ui=2.0, est=2.6065153917363855, details={'was_impossible': False}),
#  Prediction(uid='807', iid='602', r_ui=5.0, est=3.951965537229074, details={'was_impossible': False}),
#  Prediction(uid='677', iid='237', r_ui=4.0, est=4.179190716252492, details={'was_impossible': False}),
#  Prediction(uid='372', iid='201', r_ui=2.0, est=4.293867877029098, details={'was_impossible': False}),
#  Prediction(uid='7', iid='528', r_ui=5.0, est=4.464257040550478, details={'was_impossible': False}),
#  Prediction(uid='60', iid='493', r_ui=5.0, est=4.236272309909819, details={'was_impossible': False}),
#  Prediction(uid='883', iid='285', r_ui=5.0, est=4.476250875601053, details={'was_impossible': False}),
#  Prediction(uid='566', iid='384', r_ui=3.0, est=2.5201748382556484, details={'was_impossible': False}),
#  Prediction(uid='146', iid='1293', r_ui=5.0, est=3.727546710571456, details={'was_impossible': False}),
#  Prediction(uid='813', iid='300', r_ui=4.0, est=3.3172485500792424, details={'was_impossible': False}),
#  Prediction(uid='677', iid='322', r_ui=4.0, est=3.8737257056179466, details={'was_impossible': False}),
#  Prediction(uid='634', iid='290', r_ui=3.0, est=2.991441242180607, details={'was_impossible': False}),
#  Prediction(uid='596', iid='895', r_ui=3.0, est=3.296435791544302, details={'was_impossible': False}),
#  Prediction(uid='774', iid='508', r_ui=3.0, est=2.3087055840474386, details={'was_impossible': False}),
#  Prediction(uid='222', iid='241', r_ui=3.0, est=3.7273825807163132, details={'was_impossible': False}),
#  Prediction(uid='174', iid='1001', r_ui=1.0, est=2.7225601268766124, details={'was_impossible': False}),
#  Prediction(uid='910', iid='628', r_ui=1.0, est=3.3227205042682506, details={'was_impossible': False}),
#  Prediction(uid='823', iid='135', r_ui=4.0, est=4.634930204046317, details={'was_impossible': False}),
#  Prediction(uid='279', iid='50', r_ui=3.0, est=3.9249070120427785, details={'was_impossible': False}),
#  Prediction(uid='56', iid='575', r_ui=3.0, est=2.951486650531204, details={'was_impossible': False}),
#  Prediction(uid='838', iid='255', r_ui=4.0, est=3.761823914566282, details={'was_impossible': False}),
#  Prediction(uid='593', iid='255', r_ui=5.0, est=3.115504514570395, details={'was_impossible': False}),
#  Prediction(uid='54', iid='118', r_ui=4.0, est=3.5826077011014053, details={'was_impossible': False}),
#  Prediction(uid='393', iid='926', r_ui=4.0, est=2.7939250194020278, details={'was_impossible': False}),
#  Prediction(uid='435', iid='715', r_ui=3.0, est=3.4444336174543597, details={'was_impossible': False}),
#  Prediction(uid='244', iid='1136', r_ui=3.0, est=3.8123089916276736, details={'was_impossible': False}),
#  Prediction(uid='276', iid='66', r_ui=3.0, est=3.5693633983600064, details={'was_impossible': False}),
#  Prediction(uid='538', iid='168', r_ui=3.0, est=3.6863839380455867, details={'was_impossible': False}),
#  Prediction(uid='8', iid='243', r_ui=2.0, est=2.726707718807819, details={'was_impossible': False}),
#  Prediction(uid='13', iid='831', r_ui=3.0, est=2.0292913976134557, details={'was_impossible': False}),
#  Prediction(uid='750', iid='749', r_ui=3.0, est=3.5116199261469867, details={'was_impossible': False}),
#  Prediction(uid='703', iid='222', r_ui=4.0, est=4.133125504733416, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1087', r_ui=1.0, est=1.1758376378065467, details={'was_impossible': False}),
#  Prediction(uid='137', iid='1117', r_ui=2.0, est=3.875242268340468, details={'was_impossible': False}),
#  Prediction(uid='658', iid='8', r_ui=5.0, est=3.660469918150871, details={'was_impossible': False}),
#  Prediction(uid='934', iid='972', r_ui=3.0, est=3.160648429654092, details={'was_impossible': False}),
#  Prediction(uid='234', iid='836', r_ui=4.0, est=3.2080845934016726, details={'was_impossible': False}),
#  Prediction(uid='486', iid='250', r_ui=1.0, est=3.5702113369278416, details={'was_impossible': False}),
#  Prediction(uid='234', iid='1184', r_ui=2.0, est=2.47346300287921, details={'was_impossible': False}),
#  Prediction(uid='479', iid='137', r_ui=4.0, est=3.92024585236765, details={'was_impossible': False}),
#  Prediction(uid='303', iid='153', r_ui=5.0, est=4.072478948963867, details={'was_impossible': False}),
#  Prediction(uid='246', iid='384', r_ui=2.0, est=2.5506273487146633, details={'was_impossible': False}),
#  Prediction(uid='489', iid='328', r_ui=4.0, est=3.9693095156955733, details={'was_impossible': False}),
#  Prediction(uid='843', iid='403', r_ui=2.0, est=2.700883387874067, details={'was_impossible': False}),
#  Prediction(uid='749', iid='96', r_ui=5.0, est=4.17049694929303, details={'was_impossible': False}),
#  Prediction(uid='772', iid='327', r_ui=4.0, est=3.9594947352282084, details={'was_impossible': False}),
#  Prediction(uid='310', iid='845', r_ui=5.0, est=3.513371710586134, details={'was_impossible': False}),
#  Prediction(uid='427', iid='331', r_ui=4.0, est=4.365228233007614, details={'was_impossible': False}),
#  Prediction(uid='392', iid='491', r_ui=5.0, est=4.2567725485190255, details={'was_impossible': False}),
#  Prediction(uid='375', iid='183', r_ui=5.0, est=3.909205031951355, details={'was_impossible': False}),
#  Prediction(uid='690', iid='663', r_ui=4.0, est=3.4080833355642364, details={'was_impossible': False}),
#  Prediction(uid='385', iid='236', r_ui=2.0, est=3.262092008997071, details={'was_impossible': False}),
#  Prediction(uid='177', iid='238', r_ui=3.0, est=4.172350127111101, details={'was_impossible': False}),
#  Prediction(uid='145', iid='51', r_ui=3.0, est=3.6027463386617105, details={'was_impossible': False}),
#  Prediction(uid='629', iid='357', r_ui=4.0, est=4.908783341760577, details={'was_impossible': False}),
#  Prediction(uid='837', iid='1009', r_ui=5.0, est=3.226936823787038, details={'was_impossible': False}),
#  Prediction(uid='807', iid='473', r_ui=3.0, est=3.5189029837173904, details={'was_impossible': False}),
#  Prediction(uid='747', iid='474', r_ui=5.0, est=4.984193102725188, details={'was_impossible': False}),
#  Prediction(uid='263', iid='194', r_ui=5.0, est=4.509561918289621, details={'was_impossible': False}),
#  Prediction(uid='381', iid='124', r_ui=5.0, est=4.174045193999896, details={'was_impossible': False}),
#  Prediction(uid='588', iid='132', r_ui=5.0, est=4.125036864012541, details={'was_impossible': False}),
#  Prediction(uid='305', iid='478', r_ui=3.0, est=3.4394484483120147, details={'was_impossible': False}),
#  Prediction(uid='524', iid='319', r_ui=4.0, est=3.3427843724834476, details={'was_impossible': False}),
#  Prediction(uid='587', iid='319', r_ui=3.0, est=3.1856263297829517, details={'was_impossible': False}),
#  Prediction(uid='363', iid='1099', r_ui=2.0, est=2.9156256371347653, details={'was_impossible': False}),
#  Prediction(uid='388', iid='508', r_ui=3.0, est=4.02395043365326, details={'was_impossible': False}),
#  Prediction(uid='422', iid='672', r_ui=3.0, est=2.9127369729079353, details={'was_impossible': False}),
#  Prediction(uid='416', iid='385', r_ui=5.0, est=4.384497235105281, details={'was_impossible': False}),
#  Prediction(uid='234', iid='632', r_ui=2.0, est=3.549487021442497, details={'was_impossible': False}),
#  Prediction(uid='311', iid='64', r_ui=5.0, est=4.551168356529706, details={'was_impossible': False}),
#  Prediction(uid='648', iid='199', r_ui=4.0, est=4.110021103193965, details={'was_impossible': False}),
#  Prediction(uid='357', iid='687', r_ui=3.0, est=2.905095405372057, details={'was_impossible': False}),
#  Prediction(uid='499', iid='326', r_ui=3.0, est=3.1840049127513237, details={'was_impossible': False}),
#  Prediction(uid='573', iid='423', r_ui=3.0, est=3.7781287916022546, details={'was_impossible': False}),
#  Prediction(uid='457', iid='15', r_ui=4.0, est=4.184275588512267, details={'was_impossible': False}),
#  Prediction(uid='85', iid='1131', r_ui=4.0, est=3.600210212899631, details={'was_impossible': False}),
#  Prediction(uid='883', iid='347', r_ui=4.0, est=4.04637280983166, details={'was_impossible': False}),
#  Prediction(uid='354', iid='313', r_ui=3.0, est=3.8194237404274096, details={'was_impossible': False}),
#  Prediction(uid='435', iid='193', r_ui=3.0, est=3.941741174838442, details={'was_impossible': False}),
#  Prediction(uid='760', iid='98', r_ui=3.0, est=3.8533986293948828, details={'was_impossible': False}),
#  Prediction(uid='230', iid='405', r_ui=4.0, est=3.771281717966749, details={'was_impossible': False}),
#  Prediction(uid='864', iid='265', r_ui=5.0, est=4.059368288281611, details={'was_impossible': False}),
#  Prediction(uid='215', iid='22', r_ui=3.0, est=4.042247046511414, details={'was_impossible': False}),
#  Prediction(uid='666', iid='206', r_ui=4.0, est=3.4860100071560276, details={'was_impossible': False}),
#  Prediction(uid='551', iid='280', r_ui=3.0, est=3.836727180320371, details={'was_impossible': False}),
#  Prediction(uid='434', iid='275', r_ui=3.0, est=4.470105990347469, details={'was_impossible': False}),
#  Prediction(uid='269', iid='22', r_ui=1.0, est=2.963783648601045, details={'was_impossible': False}),
#  Prediction(uid='773', iid='840', r_ui=1.0, est=2.804504720083175, details={'was_impossible': False}),
#  Prediction(uid='448', iid='303', r_ui=4.0, est=3.6159303801477174, details={'was_impossible': False}),
#  Prediction(uid='405', iid='341', r_ui=1.0, est=1.1857708639558875, details={'was_impossible': False}),
#  Prediction(uid='778', iid='568', r_ui=3.0, est=2.934001189469638, details={'was_impossible': False}),
#  Prediction(uid='126', iid='881', r_ui=5.0, est=2.8563855123938278, details={'was_impossible': False}),
#  Prediction(uid='489', iid='342', r_ui=3.0, est=3.820455055827113, details={'was_impossible': False}),
#  Prediction(uid='372', iid='332', r_ui=4.0, est=4.3492506093486, details={'was_impossible': False}),
#  Prediction(uid='3', iid='303', r_ui=3.0, est=3.513262459125989, details={'was_impossible': False}),
#  Prediction(uid='620', iid='769', r_ui=4.0, est=3.5246220251628926, details={'was_impossible': False}),
#  Prediction(uid='270', iid='815', r_ui=4.0, est=4.035940334886291, details={'was_impossible': False}),
#  Prediction(uid='410', iid='300', r_ui=3.0, est=3.4046116096447854, details={'was_impossible': False}),
#  Prediction(uid='294', iid='79', r_ui=4.0, est=4.338138600616923, details={'was_impossible': False}),
#  Prediction(uid='390', iid='283', r_ui=4.0, est=4.187969542039419, details={'was_impossible': False}),
#  Prediction(uid='661', iid='135', r_ui=5.0, est=4.278034873313356, details={'was_impossible': False}),
#  Prediction(uid='188', iid='237', r_ui=3.0, est=3.8110475822775713, details={'was_impossible': False}),
#  Prediction(uid='217', iid='53', r_ui=1.0, est=2.9341946460102513, details={'was_impossible': False}),
#  Prediction(uid='656', iid='689', r_ui=2.0, est=2.493216245730435, details={'was_impossible': False}),
#  Prediction(uid='864', iid='546', r_ui=4.0, est=3.09657811465164, details={'was_impossible': False}),
#  Prediction(uid='385', iid='529', r_ui=4.0, est=3.846836338623515, details={'was_impossible': False}),
#  Prediction(uid='180', iid='153', r_ui=1.0, est=4.362786169498535, details={'was_impossible': False}),
#  Prediction(uid='789', iid='1161', r_ui=3.0, est=3.5813004027219244, details={'was_impossible': False}),
#  Prediction(uid='151', iid='134', r_ui=4.0, est=4.7221790962295715, details={'was_impossible': False}),
#  Prediction(uid='271', iid='529', r_ui=4.0, est=3.556227355980429, details={'was_impossible': False}),
#  Prediction(uid='650', iid='443', r_ui=5.0, est=3.3440294388828438, details={'was_impossible': False}),
#  Prediction(uid='727', iid='940', r_ui=2.0, est=2.4006017201226237, details={'was_impossible': False}),
#  Prediction(uid='789', iid='288', r_ui=3.0, est=3.6200688384487774, details={'was_impossible': False}),
#  Prediction(uid='159', iid='299', r_ui=3.0, est=2.9514004874859676, details={'was_impossible': False}),
#  Prediction(uid='417', iid='109', r_ui=2.0, est=3.1865918122912156, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1173', r_ui=1.0, est=1.580481333559308, details={'was_impossible': False}),
#  Prediction(uid='442', iid='873', r_ui=2.0, est=2.52313736951251, details={'was_impossible': False}),
#  Prediction(uid='183', iid='485', r_ui=5.0, est=3.475402085645691, details={'was_impossible': False}),
#  Prediction(uid='619', iid='515', r_ui=1.0, est=4.270096272404789, details={'was_impossible': False}),
#  Prediction(uid='94', iid='737', r_ui=4.0, est=3.2550482261528275, details={'was_impossible': False}),
#  Prediction(uid='805', iid='150', r_ui=5.0, est=3.9909138785658973, details={'was_impossible': False}),
#  Prediction(uid='271', iid='1101', r_ui=4.0, est=3.826103217189144, details={'was_impossible': False}),
#  Prediction(uid='437', iid='173', r_ui=4.0, est=3.5412373659835197, details={'was_impossible': False}),
#  Prediction(uid='357', iid='274', r_ui=4.0, est=4.255129732836858, details={'was_impossible': False}),
#  Prediction(uid='783', iid='345', r_ui=4.0, est=3.6295263724613256, details={'was_impossible': False}),
#  Prediction(uid='634', iid='287', r_ui=3.0, est=3.662666414278594, details={'was_impossible': False}),
#  Prediction(uid='407', iid='232', r_ui=3.0, est=3.1822578036166473, details={'was_impossible': False}),
#  Prediction(uid='654', iid='124', r_ui=4.0, est=4.047856421850519, details={'was_impossible': False}),
#  Prediction(uid='537', iid='1065', r_ui=1.0, est=3.180753704365123, details={'was_impossible': False}),
#  Prediction(uid='399', iid='102', r_ui=3.0, est=2.8664978022786585, details={'was_impossible': False}),
#  Prediction(uid='56', iid='373', r_ui=4.0, est=3.045056482360581, details={'was_impossible': False}),
#  Prediction(uid='110', iid='55', r_ui=3.0, est=3.1644243416670226, details={'was_impossible': False}),
#  Prediction(uid='99', iid='328', r_ui=4.0, est=3.5045514502080835, details={'was_impossible': False}),
#  Prediction(uid='271', iid='481', r_ui=3.0, est=3.5976548442847625, details={'was_impossible': False}),
#  Prediction(uid='71', iid='302', r_ui=3.0, est=3.916824944541498, details={'was_impossible': False}),
#  Prediction(uid='622', iid='117', r_ui=4.0, est=3.533716240555807, details={'was_impossible': False}),
#  Prediction(uid='407', iid='168', r_ui=5.0, est=3.87229268269169, details={'was_impossible': False}),
#  Prediction(uid='694', iid='1455', r_ui=3.0, est=3.701099817508808, details={'was_impossible': False}),
#  Prediction(uid='330', iid='1028', r_ui=4.0, est=3.882852876357661, details={'was_impossible': False}),
#  Prediction(uid='569', iid='458', r_ui=2.0, est=3.153998889993855, details={'was_impossible': False}),
#  Prediction(uid='354', iid='196', r_ui=3.0, est=3.809525475406866, details={'was_impossible': False}),
#  Prediction(uid='452', iid='183', r_ui=4.0, est=3.481060784175212, details={'was_impossible': False}),
#  Prediction(uid='312', iid='615', r_ui=4.0, est=4.833125175727224, details={'was_impossible': False}),
#  Prediction(uid='271', iid='428', r_ui=4.0, est=3.729335888263675, details={'was_impossible': False}),
#  Prediction(uid='303', iid='64', r_ui=5.0, est=4.4280354253275345, details={'was_impossible': False}),
#  Prediction(uid='790', iid='215', r_ui=2.0, est=3.2412532747354073, details={'was_impossible': False}),
#  Prediction(uid='94', iid='1012', r_ui=4.0, est=3.8726894997608023, details={'was_impossible': False}),
#  Prediction(uid='735', iid='285', r_ui=4.0, est=4.163552338309362, details={'was_impossible': False}),
#  Prediction(uid='389', iid='378', r_ui=5.0, est=3.6711207979248592, details={'was_impossible': False}),
#  Prediction(uid='554', iid='132', r_ui=4.0, est=4.181067569746116, details={'was_impossible': False}),
#  Prediction(uid='11', iid='722', r_ui=3.0, est=2.9558198104342255, details={'was_impossible': False}),
#  Prediction(uid='755', iid='688', r_ui=3.0, est=1.9091253960751937, details={'was_impossible': False}),
#  Prediction(uid='92', iid='1023', r_ui=2.0, est=2.6888728675825964, details={'was_impossible': False}),
#  Prediction(uid='209', iid='50', r_ui=5.0, est=4.139115308701052, details={'was_impossible': False}),
#  Prediction(uid='516', iid='582', r_ui=5.0, est=3.7082694429150735, details={'was_impossible': False}),
#  Prediction(uid='627', iid='162', r_ui=3.0, est=3.378819541517302, details={'was_impossible': False}),
#  Prediction(uid='506', iid='323', r_ui=3.0, est=3.2043898096981334, details={'was_impossible': False}),
#  Prediction(uid='450', iid='393', r_ui=4.0, est=4.009024487604147, details={'was_impossible': False}),
#  Prediction(uid='5', iid='442', r_ui=1.0, est=2.7421596676454887, details={'was_impossible': False}),
#  Prediction(uid='87', iid='252', r_ui=3.0, est=3.550475780768883, details={'was_impossible': False}),
#  Prediction(uid='76', iid='324', r_ui=4.0, est=3.289225780789601, details={'was_impossible': False}),
#  Prediction(uid='5', iid='241', r_ui=1.0, est=2.8156310721120272, details={'was_impossible': False}),
#  Prediction(uid='379', iid='403', r_ui=4.0, est=3.8905430794378373, details={'was_impossible': False}),
#  Prediction(uid='347', iid='230', r_ui=4.0, est=3.9361499835277436, details={'was_impossible': False}),
#  Prediction(uid='314', iid='1014', r_ui=3.0, est=3.3449831551053437, details={'was_impossible': False}),
#  Prediction(uid='151', iid='175', r_ui=5.0, est=4.272954116855726, details={'was_impossible': False}),
#  Prediction(uid='832', iid='260', r_ui=3.0, est=2.2502648920041617, details={'was_impossible': False}),
#  Prediction(uid='221', iid='128', r_ui=3.0, est=3.9916313589010914, details={'was_impossible': False}),
#  Prediction(uid='137', iid='79', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='901', iid='1643', r_ui=5.0, est=4.060597865396163, details={'was_impossible': False}),
#  Prediction(uid='875', iid='171', r_ui=5.0, est=4.1408026501611594, details={'was_impossible': False}),
#  Prediction(uid='117', iid='33', r_ui=4.0, est=3.932881301396273, details={'was_impossible': False}),
#  Prediction(uid='592', iid='654', r_ui=5.0, est=4.708930701834884, details={'was_impossible': False}),
#  Prediction(uid='436', iid='127', r_ui=5.0, est=4.529824513422745, details={'was_impossible': False}),
#  Prediction(uid='276', iid='57', r_ui=3.0, est=4.234935376908685, details={'was_impossible': False}),
#  Prediction(uid='399', iid='48', r_ui=3.0, est=3.634495884505324, details={'was_impossible': False}),
#  Prediction(uid='303', iid='328', r_ui=3.0, est=2.084262439054233, details={'was_impossible': False}),
#  Prediction(uid='168', iid='125', r_ui=4.0, est=3.5610189256228644, details={'was_impossible': False}),
#  Prediction(uid='896', iid='1004', r_ui=2.0, est=2.7986142038817747, details={'was_impossible': False}),
#  Prediction(uid='543', iid='324', r_ui=3.0, est=3.3305564310706717, details={'was_impossible': False}),
#  Prediction(uid='16', iid='385', r_ui=5.0, est=4.42889298743607, details={'was_impossible': False}),
#  Prediction(uid='639', iid='519', r_ui=4.0, est=3.1025868774122554, details={'was_impossible': False}),
#  Prediction(uid='835', iid='204', r_ui=3.0, est=4.297773694196783, details={'was_impossible': False}),
#  Prediction(uid='159', iid='195', r_ui=3.0, est=4.038396274090262, details={'was_impossible': False}),
#  Prediction(uid='270', iid='1073', r_ui=5.0, est=4.746440324763444, details={'was_impossible': False}),
#  Prediction(uid='107', iid='268', r_ui=4.0, est=3.1807287758002283, details={'was_impossible': False}),
#  Prediction(uid='262', iid='55', r_ui=3.0, est=3.296357302727367, details={'was_impossible': False}),
#  Prediction(uid='796', iid='118', r_ui=4.0, est=3.992819651012258, details={'was_impossible': False}),
#  Prediction(uid='688', iid='359', r_ui=5.0, est=4.954868847753163, details={'was_impossible': False}),
#  Prediction(uid='498', iid='448', r_ui=4.0, est=3.0394426946133195, details={'was_impossible': False}),
#  Prediction(uid='814', iid='56', r_ui=3.0, est=3.905948499570477, details={'was_impossible': False}),
#  Prediction(uid='566', iid='386', r_ui=1.0, est=2.513661155524474, details={'was_impossible': False}),
#  Prediction(uid='5', iid='363', r_ui=3.0, est=2.6289115813092536, details={'was_impossible': False}),
#  Prediction(uid='361', iid='794', r_ui=3.0, est=3.508536187267384, details={'was_impossible': False}),
#  Prediction(uid='197', iid='187', r_ui=5.0, est=3.661419047388296, details={'was_impossible': False}),
#  Prediction(uid='294', iid='300', r_ui=4.0, est=3.6948088853246617, details={'was_impossible': False}),
#  Prediction(uid='664', iid='805', r_ui=5.0, est=3.4283489578830904, details={'was_impossible': False}),
#  Prediction(uid='110', iid='895', r_ui=2.0, est=3.1372683130954266, details={'was_impossible': False}),
#  Prediction(uid='268', iid='158', r_ui=2.0, est=1.8546512197438867, details={'was_impossible': False}),
#  Prediction(uid='407', iid='50', r_ui=4.0, est=4.486383947797199, details={'was_impossible': False}),
#  Prediction(uid='53', iid='284', r_ui=2.0, est=3.7354910221930675, details={'was_impossible': False}),
#  Prediction(uid='912', iid='655', r_ui=5.0, est=3.696980786367646, details={'was_impossible': False}),
#  Prediction(uid='64', iid='655', r_ui=4.0, est=3.6190721317956274, details={'was_impossible': False}),
#  Prediction(uid='666', iid='179', r_ui=5.0, est=4.232869999342783, details={'was_impossible': False}),
#  Prediction(uid='332', iid='284', r_ui=5.0, est=3.890633044437781, details={'was_impossible': False}),
#  Prediction(uid='82', iid='197', r_ui=4.0, est=3.6048814759042647, details={'was_impossible': False}),
#  Prediction(uid='654', iid='118', r_ui=2.0, est=3.2126413964911134, details={'was_impossible': False}),
#  Prediction(uid='409', iid='28', r_ui=2.0, est=3.7393536540743835, details={'was_impossible': False}),
#  Prediction(uid='210', iid='44', r_ui=3.0, est=3.8768109593242097, details={'was_impossible': False}),
#  Prediction(uid='374', iid='237', r_ui=5.0, est=3.8206735328792587, details={'was_impossible': False}),
#  Prediction(uid='249', iid='50', r_ui=4.0, est=4.279572586084931, details={'was_impossible': False}),
#  Prediction(uid='888', iid='100', r_ui=4.0, est=4.488860090985152, details={'was_impossible': False}),
#  Prediction(uid='95', iid='648', r_ui=3.0, est=3.7067954934955947, details={'was_impossible': False}),
#  Prediction(uid='120', iid='742', r_ui=4.0, est=3.656601408774203, details={'was_impossible': False}),
#  Prediction(uid='145', iid='1009', r_ui=2.0, est=3.128181115077893, details={'was_impossible': False}),
#  Prediction(uid='201', iid='285', r_ui=4.0, est=3.5769657258998553, details={'was_impossible': False}),
#  Prediction(uid='804', iid='200', r_ui=3.0, est=3.738417923728428, details={'was_impossible': False}),
#  Prediction(uid='208', iid='202', r_ui=4.0, est=3.878251574647398, details={'was_impossible': False}),
#  Prediction(uid='727', iid='507', r_ui=2.0, est=3.5827292924052543, details={'was_impossible': False}),
#  Prediction(uid='919', iid='25', r_ui=4.0, est=3.296453336118485, details={'was_impossible': False}),
#  Prediction(uid='216', iid='824', r_ui=3.0, est=2.474113393126902, details={'was_impossible': False}),
#  Prediction(uid='716', iid='340', r_ui=3.0, est=3.742247168621322, details={'was_impossible': False}),
#  Prediction(uid='595', iid='275', r_ui=4.0, est=4.234708532528803, details={'was_impossible': False}),
#  Prediction(uid='450', iid='86', r_ui=4.0, est=4.359118496435217, details={'was_impossible': False}),
#  Prediction(uid='244', iid='197', r_ui=4.0, est=4.345578042316956, details={'was_impossible': False}),
#  Prediction(uid='870', iid='1021', r_ui=2.0, est=3.712258975105669, details={'was_impossible': False}),
#  Prediction(uid='342', iid='574', r_ui=1.0, est=2.1914819590935286, details={'was_impossible': False}),
#  Prediction(uid='665', iid='687', r_ui=2.0, est=2.4446245854227606, details={'was_impossible': False}),
#  Prediction(uid='864', iid='549', r_ui=3.0, est=4.107219210616868, details={'was_impossible': False}),
#  Prediction(uid='321', iid='480', r_ui=4.0, est=4.142520246909155, details={'was_impossible': False}),
#  Prediction(uid='187', iid='186', r_ui=4.0, est=4.311728062313329, details={'was_impossible': False}),
#  Prediction(uid='392', iid='98', r_ui=5.0, est=4.395603887960638, details={'was_impossible': False}),
#  Prediction(uid='64', iid='93', r_ui=2.0, est=3.923459947658835, details={'was_impossible': False}),
#  Prediction(uid='303', iid='47', r_ui=5.0, est=4.3553841449804835, details={'was_impossible': False}),
#  Prediction(uid='412', iid='4', r_ui=3.0, est=3.7648222643365314, details={'was_impossible': False}),
#  Prediction(uid='58', iid='490', r_ui=4.0, est=3.906031793684312, details={'was_impossible': False}),
#  Prediction(uid='376', iid='181', r_ui=4.0, est=3.9457540531767736, details={'was_impossible': False}),
#  Prediction(uid='833', iid='1597', r_ui=5.0, est=2.91620539894604, details={'was_impossible': False}),
#  Prediction(uid='644', iid='326', r_ui=5.0, est=3.8609957997375077, details={'was_impossible': False}),
#  Prediction(uid='372', iid='674', r_ui=5.0, est=3.97480154832464, details={'was_impossible': False}),
#  Prediction(uid='5', iid='239', r_ui=4.0, est=2.8948679412959812, details={'was_impossible': False}),
#  Prediction(uid='216', iid='72', r_ui=2.0, est=3.463800476321912, details={'was_impossible': False}),
#  Prediction(uid='907', iid='934', r_ui=4.0, est=3.9603628723189126, details={'was_impossible': False}),
#  Prediction(uid='262', iid='485', r_ui=4.0, est=3.535966731894026, details={'was_impossible': False}),
#  Prediction(uid='760', iid='1135', r_ui=4.0, est=3.084371418609562, details={'was_impossible': False}),
#  Prediction(uid='145', iid='1090', r_ui=2.0, est=2.321051464433892, details={'was_impossible': False}),
#  Prediction(uid='442', iid='508', r_ui=3.0, est=3.509981721095802, details={'was_impossible': False}),
#  Prediction(uid='13', iid='92', r_ui=3.0, est=2.927864884672227, details={'was_impossible': False}),
#  Prediction(uid='807', iid='89', r_ui=4.0, est=3.9434081769208467, details={'was_impossible': False}),
#  Prediction(uid='176', iid='257', r_ui=1.0, est=4.381364078447701, details={'was_impossible': False}),
#  Prediction(uid='883', iid='275', r_ui=4.0, est=4.223172584108281, details={'was_impossible': False}),
#  Prediction(uid='725', iid='9', r_ui=4.0, est=4.718599789280306, details={'was_impossible': False}),
#  Prediction(uid='346', iid='161', r_ui=3.0, est=3.419926480093744, details={'was_impossible': False}),
#  Prediction(uid='559', iid='144', r_ui=5.0, est=3.5642984263034263, details={'was_impossible': False}),
#  Prediction(uid='291', iid='798', r_ui=4.0, est=3.0484413918569477, details={'was_impossible': False}),
#  Prediction(uid='249', iid='258', r_ui=5.0, est=4.179739726697857, details={'was_impossible': False}),
#  Prediction(uid='155', iid='294', r_ui=3.0, est=2.8573460198106693, details={'was_impossible': False}),
#  Prediction(uid='271', iid='1266', r_ui=2.0, est=3.155483275630251, details={'was_impossible': False}),
#  Prediction(uid='174', iid='143', r_ui=5.0, est=4.035269212763419, details={'was_impossible': False}),
#  Prediction(uid='807', iid='576', r_ui=4.0, est=3.904719167045406, details={'was_impossible': False}),
#  Prediction(uid='500', iid='164', r_ui=4.0, est=3.074288732225001, details={'was_impossible': False}),
#  Prediction(uid='893', iid='286', r_ui=4.0, est=2.945014418842679, details={'was_impossible': False}),
#  Prediction(uid='44', iid='756', r_ui=3.0, est=3.006846210239669, details={'was_impossible': False}),
#  Prediction(uid='893', iid='24', r_ui=4.0, est=3.6478790406329713, details={'was_impossible': False}),
#  Prediction(uid='463', iid='936', r_ui=2.0, est=3.1883810703841764, details={'was_impossible': False}),
#  Prediction(uid='70', iid='472', r_ui=3.0, est=2.7226484922464445, details={'was_impossible': False}),
#  Prediction(uid='194', iid='488', r_ui=3.0, est=3.5795655172987795, details={'was_impossible': False}),
#  Prediction(uid='246', iid='679', r_ui=2.0, est=2.915657363975301, details={'was_impossible': False}),
#  Prediction(uid='200', iid='748', r_ui=3.0, est=4.0364916232723695, details={'was_impossible': False}),
#  Prediction(uid='403', iid='1199', r_ui=2.0, est=3.0097103840000567, details={'was_impossible': False}),
#  Prediction(uid='479', iid='470', r_ui=5.0, est=3.428571547848663, details={'was_impossible': False}),
#  Prediction(uid='592', iid='886', r_ui=3.0, est=3.4156529482739066, details={'was_impossible': False}),
#  Prediction(uid='450', iid='23', r_ui=5.0, est=4.1190179246845995, details={'was_impossible': False}),
#  Prediction(uid='551', iid='627', r_ui=3.0, est=3.4132160071788644, details={'was_impossible': False}),
#  Prediction(uid='328', iid='159', r_ui=3.0, est=3.2014330629532948, details={'was_impossible': False}),
#  Prediction(uid='796', iid='880', r_ui=3.0, est=3.360554693356381, details={'was_impossible': False}),
#  Prediction(uid='551', iid='172', r_ui=2.0, est=4.3995163010699585, details={'was_impossible': False}),
#  Prediction(uid='234', iid='1048', r_ui=3.0, est=2.9278683192461568, details={'was_impossible': False}),
#  Prediction(uid='798', iid='946', r_ui=2.0, est=3.1780928837728926, details={'was_impossible': False}),
#  Prediction(uid='571', iid='462', r_ui=4.0, est=3.3486762439217426, details={'was_impossible': False}),
#  Prediction(uid='339', iid='139', r_ui=3.0, est=3.098497277345376, details={'was_impossible': False}),
#  Prediction(uid='354', iid='929', r_ui=4.0, est=2.736979489110847, details={'was_impossible': False}),
#  Prediction(uid='551', iid='423', r_ui=1.0, est=3.9387064218554224, details={'was_impossible': False}),
#  Prediction(uid='698', iid='707', r_ui=2.0, est=2.8061750769944647, details={'was_impossible': False}),
#  Prediction(uid='549', iid='127', r_ui=5.0, est=4.064819490705409, details={'was_impossible': False}),
#  Prediction(uid='331', iid='868', r_ui=4.0, est=3.340462783934311, details={'was_impossible': False}),
#  Prediction(uid='584', iid='449', r_ui=2.0, est=3.231281247041574, details={'was_impossible': False}),
# ...
#  Prediction(uid='621', iid='181', r_ui=5.0, est=4.701075618016743, details={'was_impossible': False}),
#  Prediction(uid='935', iid='471', r_ui=4.0, est=4.337528799670405, details={'was_impossible': False}),
#  Prediction(uid='592', iid='332', r_ui=3.0, est=4.049704570015571, details={'was_impossible': False}),
#  Prediction(uid='541', iid='140', r_ui=5.0, est=3.351543791957988, details={'was_impossible': False}),
#  Prediction(uid='327', iid='338', r_ui=1.0, est=2.4733102312304527, details={'was_impossible': False}),
#  Prediction(uid='907', iid='281', r_ui=5.0, est=4.3267335796021715, details={'was_impossible': False}),
#  Prediction(uid='314', iid='790', r_ui=4.0, est=3.6128131402381745, details={'was_impossible': False}),
#  Prediction(uid='5', iid='380', r_ui=3.0, est=3.0329785998802854, details={'was_impossible': False}),
#  Prediction(uid='223', iid='470', r_ui=4.0, est=3.14132688369908, details={'was_impossible': False}),
#  Prediction(uid='603', iid='1240', r_ui=5.0, est=3.7437357394825823, details={'was_impossible': False}),
#  Prediction(uid='934', iid='204', r_ui=4.0, est=4.0375191410486755, details={'was_impossible': False}),
#  Prediction(uid='567', iid='223', r_ui=4.0, est=4.214029876960093, details={'was_impossible': False}),
#  Prediction(uid='671', iid='255', r_ui=5.0, est=3.9329488236602965, details={'was_impossible': False}),
#  Prediction(uid='234', iid='712', r_ui=2.0, est=2.585600729178007, details={'was_impossible': False}),
#  Prediction(uid='186', iid='263', r_ui=3.0, est=2.5359164018680196, details={'was_impossible': False}),
#  Prediction(uid='496', iid='509', r_ui=3.0, est=3.031518019145783, details={'was_impossible': False}),
#  Prediction(uid='454', iid='427', r_ui=4.0, est=3.3156207879753454, details={'was_impossible': False}),
#  Prediction(uid='483', iid='199', r_ui=3.0, est=3.6480183995001445, details={'was_impossible': False}),
#  Prediction(uid='664', iid='778', r_ui=3.0, est=3.7253133502930678, details={'was_impossible': False}),
#  Prediction(uid='48', iid='266', r_ui=3.0, est=2.9489745702259076, details={'was_impossible': False}),
#  Prediction(uid='429', iid='481', r_ui=3.0, est=3.686604715091394, details={'was_impossible': False}),
#  Prediction(uid='124', iid='154', r_ui=5.0, est=3.3555733606451734, details={'was_impossible': False}),
#  Prediction(uid='533', iid='98', r_ui=4.0, est=3.7745839804653882, details={'was_impossible': False}),
#  Prediction(uid='854', iid='191', r_ui=4.0, est=3.844708877136801, details={'was_impossible': False}),
#  Prediction(uid='643', iid='928', r_ui=4.0, est=2.855251968487682, details={'was_impossible': False}),
#  Prediction(uid='210', iid='274', r_ui=5.0, est=3.9509245606648395, details={'was_impossible': False}),
#  Prediction(uid='116', iid='1089', r_ui=2.0, est=1.5778212239290412, details={'was_impossible': False}),
#  Prediction(uid='429', iid='2', r_ui=3.0, est=3.0008929541075844, details={'was_impossible': False}),
#  Prediction(uid='435', iid='501', r_ui=3.0, est=3.111427276019785, details={'was_impossible': False}),
#  Prediction(uid='757', iid='157', r_ui=3.0, est=3.565746519711949, details={'was_impossible': False}),
#  Prediction(uid='916', iid='470', r_ui=3.0, est=3.395525660920691, details={'was_impossible': False}),
#  Prediction(uid='465', iid='855', r_ui=4.0, est=3.2593587625661624, details={'was_impossible': False}),
#  Prediction(uid='406', iid='9', r_ui=5.0, est=3.711887356983374, details={'was_impossible': False}),
#  Prediction(uid='643', iid='92', r_ui=4.0, est=3.391563492671915, details={'was_impossible': False}),
#  Prediction(uid='399', iid='393', r_ui=4.0, est=2.996235394790921, details={'was_impossible': False}),
#  Prediction(uid='862', iid='177', r_ui=4.0, est=4.557155675806993, details={'was_impossible': False}),
#  Prediction(uid='268', iid='802', r_ui=3.0, est=2.137971982155263, details={'was_impossible': False}),
#  Prediction(uid='82', iid='717', r_ui=1.0, est=2.525990604359026, details={'was_impossible': False}),
#  Prediction(uid='601', iid='8', r_ui=3.0, est=3.591614853979688, details={'was_impossible': False}),
#  Prediction(uid='499', iid='328', r_ui=5.0, est=3.3622711399140495, details={'was_impossible': False}),
#  Prediction(uid='843', iid='1135', r_ui=3.0, est=2.274577646368323, details={'was_impossible': False}),
#  Prediction(uid='854', iid='1028', r_ui=2.0, est=2.7134704774590346, details={'was_impossible': False}),
#  Prediction(uid='90', iid='962', r_ui=2.0, est=3.8497042331237026, details={'was_impossible': False}),
#  Prediction(uid='239', iid='134', r_ui=5.0, est=4.49926542920827, details={'was_impossible': False}),
#  Prediction(uid='339', iid='170', r_ui=5.0, est=4.667692690182675, details={'was_impossible': False}),
#  Prediction(uid='851', iid='273', r_ui=5.0, est=3.7585639711770025, details={'was_impossible': False}),
#  Prediction(uid='627', iid='802', r_ui=2.0, est=2.566601273357475, details={'was_impossible': False}),
#  Prediction(uid='280', iid='499', r_ui=4.0, est=4.410414906411905, details={'was_impossible': False}),
#  Prediction(uid='785', iid='294', r_ui=4.0, est=2.9141524565288077, details={'was_impossible': False}),
#  Prediction(uid='899', iid='29', r_ui=2.0, est=2.4643922528923943, details={'was_impossible': False}),
#  Prediction(uid='95', iid='542', r_ui=2.0, est=2.7368214307337815, details={'was_impossible': False}),
#  Prediction(uid='653', iid='944', r_ui=2.0, est=2.1554909899320833, details={'was_impossible': False}),
#  Prediction(uid='458', iid='1338', r_ui=3.0, est=3.5566369454175026, details={'was_impossible': False}),
#  Prediction(uid='676', iid='471', r_ui=3.0, est=3.727517538217359, details={'was_impossible': False}),
#  Prediction(uid='117', iid='156', r_ui=4.0, est=4.630329426239794, details={'was_impossible': False}),
#  Prediction(uid='682', iid='713', r_ui=3.0, est=3.2509978206421675, details={'was_impossible': False}),
#  Prediction(uid='880', iid='755', r_ui=3.0, est=3.478800071752088, details={'was_impossible': False}),
#  Prediction(uid='389', iid='133', r_ui=5.0, est=3.5468673567879305, details={'was_impossible': False}),
#  Prediction(uid='59', iid='86', r_ui=3.0, est=4.289569149136731, details={'was_impossible': False}),
#  Prediction(uid='698', iid='228', r_ui=3.0, est=2.7294646477812985, details={'was_impossible': False}),
#  Prediction(uid='844', iid='568', r_ui=4.0, est=3.333734617308033, details={'was_impossible': False}),
#  Prediction(uid='94', iid='47', r_ui=5.0, est=4.091398015438218, details={'was_impossible': False}),
#  Prediction(uid='230', iid='435', r_ui=4.0, est=4.252021881300391, details={'was_impossible': False}),
#  Prediction(uid='268', iid='42', r_ui=4.0, est=4.109670874498475, details={'was_impossible': False}),
#  Prediction(uid='130', iid='681', r_ui=3.0, est=3.307368610398867, details={'was_impossible': False}),
#  Prediction(uid='363', iid='1', r_ui=2.0, est=3.219781079314649, details={'was_impossible': False}),
#  Prediction(uid='381', iid='89', r_ui=5.0, est=4.41306212560542, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1356', r_ui=1.0, est=1.6938387913990214, details={'was_impossible': False}),
#  Prediction(uid='911', iid='548', r_ui=3.0, est=2.8204096542030683, details={'was_impossible': False}),
#  Prediction(uid='13', iid='855', r_ui=4.0, est=3.533487139302321, details={'was_impossible': False}),
#  Prediction(uid='56', iid='746', r_ui=4.0, est=4.008181004037694, details={'was_impossible': False}),
#  Prediction(uid='130', iid='204', r_ui=5.0, est=4.676853889580946, details={'was_impossible': False}),
#  Prediction(uid='144', iid='651', r_ui=4.0, est=3.8811801932767933, details={'was_impossible': False}),
#  Prediction(uid='548', iid='293', r_ui=4.0, est=4.036316128891471, details={'was_impossible': False}),
#  Prediction(uid='756', iid='79', r_ui=4.0, est=3.586133572506937, details={'was_impossible': False}),
#  Prediction(uid='840', iid='45', r_ui=4.0, est=4.251394019396477, details={'was_impossible': False}),
#  Prediction(uid='85', iid='509', r_ui=4.0, est=3.8115851304789583, details={'was_impossible': False}),
#  Prediction(uid='520', iid='310', r_ui=4.0, est=3.6696569408716, details={'was_impossible': False}),
#  Prediction(uid='669', iid='7', r_ui=3.0, est=4.0753442994265505, details={'was_impossible': False}),
#  Prediction(uid='214', iid='117', r_ui=4.0, est=3.5604620537883602, details={'was_impossible': False}),
#  Prediction(uid='7', iid='334', r_ui=5.0, est=3.5962475087788, details={'was_impossible': False}),
#  Prediction(uid='896', iid='133', r_ui=2.0, est=2.9027647414245923, details={'was_impossible': False}),
#  Prediction(uid='774', iid='520', r_ui=3.0, est=2.9281972759481008, details={'was_impossible': False}),
#  Prediction(uid='393', iid='623', r_ui=3.0, est=2.878113635336285, details={'was_impossible': False}),
#  Prediction(uid='511', iid='260', r_ui=4.0, est=2.851863495761487, details={'was_impossible': False}),
#  Prediction(uid='122', iid='570', r_ui=3.0, est=3.456862647180342, details={'was_impossible': False}),
#  Prediction(uid='688', iid='749', r_ui=5.0, est=4.4409080724263355, details={'was_impossible': False}),
#  Prediction(uid='798', iid='204', r_ui=4.0, est=3.743610469896974, details={'was_impossible': False}),
#  Prediction(uid='106', iid='107', r_ui=4.0, est=3.4039717524627227, details={'was_impossible': False}),
#  Prediction(uid='437', iid='433', r_ui=3.0, est=3.4063082612834887, details={'was_impossible': False}),
#  Prediction(uid='606', iid='91', r_ui=5.0, est=4.041851525768704, details={'was_impossible': False}),
#  Prediction(uid='686', iid='588', r_ui=4.0, est=4.484315913566235, details={'was_impossible': False}),
#  Prediction(uid='747', iid='30', r_ui=5.0, est=4.246052784956167, details={'was_impossible': False}),
#  Prediction(uid='622', iid='90', r_ui=4.0, est=3.241000046262056, details={'was_impossible': False}),
#  Prediction(uid='624', iid='928', r_ui=3.0, est=3.223378401090214, details={'was_impossible': False}),
#  Prediction(uid='119', iid='338', r_ui=1.0, est=3.086459831306472, details={'was_impossible': False}),
#  Prediction(uid='119', iid='172', r_ui=4.0, est=4.302698014904672, details={'was_impossible': False}),
#  Prediction(uid='717', iid='24', r_ui=2.0, est=3.7944092944572434, details={'was_impossible': False}),
#  Prediction(uid='60', iid='799', r_ui=4.0, est=3.521823606806043, details={'was_impossible': False}),
#  Prediction(uid='175', iid='234', r_ui=5.0, est=3.9417776937764737, details={'was_impossible': False}),
#  Prediction(uid='314', iid='1518', r_ui=4.0, est=3.59835407234987, details={'was_impossible': False}),
#  Prediction(uid='156', iid='187', r_ui=5.0, est=3.700180668925743, details={'was_impossible': False}),
#  Prediction(uid='497', iid='441', r_ui=2.0, est=2.9195441142547383, details={'was_impossible': False}),
#  Prediction(uid='692', iid='300', r_ui=4.0, est=3.655780701711503, details={'was_impossible': False}),
#  Prediction(uid='661', iid='196', r_ui=3.0, est=3.783295517993583, details={'was_impossible': False}),
#  Prediction(uid='268', iid='370', r_ui=2.0, est=2.1003935360171004, details={'was_impossible': False}),
#  Prediction(uid='257', iid='151', r_ui=4.0, est=3.7201992920030222, details={'was_impossible': False}),
#  Prediction(uid='420', iid='190', r_ui=5.0, est=4.583093000020687, details={'was_impossible': False}),
#  Prediction(uid='821', iid='181', r_ui=4.0, est=4.751065751521706, details={'was_impossible': False}),
#  Prediction(uid='90', iid='692', r_ui=4.0, est=4.057759000155122, details={'was_impossible': False}),
#  Prediction(uid='269', iid='77', r_ui=1.0, est=2.5260975335091658, details={'was_impossible': False}),
#  Prediction(uid='746', iid='174', r_ui=5.0, est=4.272533294883438, details={'was_impossible': False}),
#  Prediction(uid='805', iid='546', r_ui=2.0, est=3.112403862713776, details={'was_impossible': False}),
#  Prediction(uid='405', iid='645', r_ui=1.0, est=2.170890546192046, details={'was_impossible': False}),
#  Prediction(uid='316', iid='289', r_ui=2.0, est=3.011498627459725, details={'was_impossible': False}),
#  Prediction(uid='860', iid='344', r_ui=3.0, est=3.38444470592572, details={'was_impossible': False}),
#  Prediction(uid='618', iid='925', r_ui=2.0, est=3.384141191351438, details={'was_impossible': False}),
#  Prediction(uid='165', iid='176', r_ui=4.0, est=4.123321942208495, details={'was_impossible': False}),
#  Prediction(uid='899', iid='98', r_ui=4.0, est=4.080578333326496, details={'was_impossible': False}),
#  Prediction(uid='184', iid='387', r_ui=4.0, est=3.5390308370485366, details={'was_impossible': False}),
#  Prediction(uid='862', iid='175', r_ui=5.0, est=4.245938090454424, details={'was_impossible': False}),
#  Prediction(uid='486', iid='690', r_ui=2.0, est=3.092242476204757, details={'was_impossible': False}),
#  Prediction(uid='683', iid='132', r_ui=5.0, est=3.7615394666845314, details={'was_impossible': False}),
#  Prediction(uid='924', iid='134', r_ui=4.0, est=4.297350612350667, details={'was_impossible': False}),
#  Prediction(uid='929', iid='521', r_ui=5.0, est=3.7179514882100286, details={'was_impossible': False}),
#  Prediction(uid='749', iid='843', r_ui=3.0, est=3.1746616384821214, details={'was_impossible': False}),
#  Prediction(uid='601', iid='427', r_ui=4.0, est=3.719235408774769, details={'was_impossible': False}),
#  Prediction(uid='655', iid='899', r_ui=2.0, est=2.972123041768802, details={'was_impossible': False}),
#  Prediction(uid='455', iid='288', r_ui=2.0, est=3.2065033576355066, details={'was_impossible': False}),
#  Prediction(uid='883', iid='83', r_ui=3.0, est=4.454488351842494, details={'was_impossible': False}),
#  Prediction(uid='663', iid='357', r_ui=5.0, est=4.413752983430068, details={'was_impossible': False}),
#  Prediction(uid='236', iid='9', r_ui=5.0, est=3.512842190212232, details={'was_impossible': False}),
#  Prediction(uid='706', iid='148', r_ui=4.0, est=3.1015076783805893, details={'was_impossible': False}),
#  Prediction(uid='7', iid='583', r_ui=2.0, est=3.6971309836488704, details={'was_impossible': False}),
#  Prediction(uid='833', iid='573', r_ui=1.0, est=2.6669585357758465, details={'was_impossible': False}),
#  Prediction(uid='232', iid='498', r_ui=4.0, est=4.050194474003224, details={'was_impossible': False}),
#  Prediction(uid='203', iid='258', r_ui=3.0, est=3.65428087334153, details={'was_impossible': False}),
#  Prediction(uid='60', iid='161', r_ui=4.0, est=3.884837134507002, details={'was_impossible': False}),
#  Prediction(uid='393', iid='1053', r_ui=3.0, est=3.455000828992226, details={'was_impossible': False}),
#  Prediction(uid='782', iid='321', r_ui=2.0, est=2.4185604150310756, details={'was_impossible': False}),
#  Prediction(uid='796', iid='1511', r_ui=3.0, est=3.7224142808851712, details={'was_impossible': False}),
#  Prediction(uid='558', iid='20', r_ui=5.0, est=3.913545343476591, details={'was_impossible': False}),
#  Prediction(uid='338', iid='443', r_ui=5.0, est=4.198037266262065, details={'was_impossible': False}),
#  Prediction(uid='654', iid='248', r_ui=2.0, est=3.4982965054456776, details={'was_impossible': False}),
#  Prediction(uid='533', iid='161', r_ui=4.0, est=3.5437275174325813, details={'was_impossible': False}),
#  Prediction(uid='346', iid='144', r_ui=4.0, est=3.889281570427861, details={'was_impossible': False}),
#  Prediction(uid='95', iid='78', r_ui=3.0, est=2.481234126519723, details={'was_impossible': False}),
#  Prediction(uid='283', iid='435', r_ui=5.0, est=4.384868006160328, details={'was_impossible': False}),
#  Prediction(uid='214', iid='23', r_ui=5.0, est=4.0999400328604665, details={'was_impossible': False}),
#  Prediction(uid='650', iid='495', r_ui=3.0, est=3.135583484020532, details={'was_impossible': False}),
#  Prediction(uid='538', iid='69', r_ui=5.0, est=3.761344847977372, details={'was_impossible': False}),
#  Prediction(uid='912', iid='501', r_ui=4.0, est=3.381597567083503, details={'was_impossible': False}),
#  Prediction(uid='393', iid='323', r_ui=2.0, est=3.1339756872117626, details={'was_impossible': False}),
#  Prediction(uid='62', iid='1073', r_ui=4.0, est=3.630276711177338, details={'was_impossible': False}),
#  Prediction(uid='429', iid='11', r_ui=4.0, est=3.4221679513052017, details={'was_impossible': False}),
#  ...]

# %%
# compute RMSE
accuracy.rmse(predictions)
# Out:
# RMSE: 0.9408
# 0.9408387079954585

# %%
# get a prediction for specific users and items.
uid = 3
iid = 15

pred = algo.predict(uid, iid, verbose=True)
# Out:
# user: 3          item: 15         r_ui = None   est = 3.53   {'was_impossible': False}

# %% [markdown]
# The model says user 3 will slightly like joke 15!
