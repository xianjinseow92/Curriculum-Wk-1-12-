# %% [markdown]
# # Gradient Boosting Machines

# %%
# command line install, uncomment line below
# !conda install -y -c conda-forge xgboost
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - xgboost
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/win-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/win-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/win-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/msys2/win-64
#   - https://repo.anaconda.com/pkgs/msys2/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
#######################
# standard code block #
#######################

# see https://ipython.readthedocs.io/en/stable/interactive/magics.html
# %pylab inline

# sets backend to render higher res images
# %config InlineBackend.figure_formats = ['retina']

#######################
#       imports       #
#######################
import pandas as pd
import seaborn as sns
from sklearn.datasets import california_housing
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import accuracy_score
import xgboost as xgb

sns.set_style("whitegrid")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Conceptual Overview & Hyperparameter Tuning with xgboost
#
# **Objectives**:
# 1. Understand the basic mathematical framework behind gradient boosted trees and the model's key hyperparameters
# 2. Understand the typical use cases for gradient boosting and some of the pros and cons
# 3. Build familiarity with the widely used xgboost package and practice selecting/tuning hyperparameters

# %% [markdown]
# ### Mathematical Framework
#
# **First Pass (Regression)**:
#
# Let's start by briefly returning to random forests. With the RF algorithm, we start with a very low bias but high variance **strong learner**, and reduce its variance by averaging across many relatively uncorrelated copies. Recall that we get these copies by injecting randomness into each base tree in the forest ensemble (taking bootstrapped samples of the training data, subsampling the feature columns for each tree split). The end result is a model that overfits less than a single decision tree due to variance reduction. See the diagram from [KDnuggets](https://www.kdnuggets.com/2017/10/random-forests-explained.html) below.
#
# ![](images/RFDiagram.jpg)
#
# Boosting models are a flipped version of this paradigm. Instead of a strong learner, we start with a high bias but low variance **weak learner** and reduce its bias by training models that iteratively correct for the mistakes made by previous models. Building a sort of tower of weak models in this fashion makes for a strong ensemble that doesn't underfit, and the low variance of each base model helps insulate the ensemble from overfitting.
#
# The most powerful variety of boosting in modern ML is **gradient boosted trees**, which we'll focus on. Our base learner is a simple decision tree with relatively small depth / few decision splits. We will build a final model by adding the results of many such trees together. The most intuitive problem setting to start with here is regression, with the usual sum of the squared errors (SSE) as the loss function we aim to minimize for data $X, y$. In each step of model building, we fit a base learner tree to the residuals of the current model's training predictions, adding it to the ensemble and gradually decreasing our training error.
#
# In (mostly) english, here's what we do:
#
# * We'll train $k$ (hyperparameter) base learner decision trees with max depth $d$ (hyperparameter) step by step, adding each to our overall model.
# * Each base tree is fit using our data $X$, but the target values are the residuals $y - model_{cur}$, where $model_{cur}$ is our overall model at that time step (sum of previous trees and initialization)
# * We initialize our model with the best constant prediction, $mean(y)$.
#
# As an algorithm:
#
# 1. Set $T_0 = mean(y)$
# 2. For $m = 1,...,k$:
#     1. Set $r_{m-1} = y - (T_0 + \sum\limits_{j=1}^{m-1}T_j(X))$
#     2. Fit max depth $d$ tree $T_m$ with features $X$, target $r_{m-1}$
#
# Obtain final model: $F(X) = T_0 + T_1(X) + ... + T_k(X)$
#
# ![](images/RegressDiagram.png)
#
# Not too complicated! But hold on, where does the *gradient* part of the name come in? And would we be able to adapt this model to a classification problem? As it turns out, the answer to both questions is the same.

# %% [markdown]
# **Generalizing GBM to Differentiable Loss Functions**:
#
# Yep, the **gradient** bit is closely related to the gradient descent algorithm that we know and love. It's also where the real power of the GBM framework becomes apparent. With the more general version of the algorithm that we'll see below, we can simply plug in a differentiable loss function and get an appropriate model.
#
# To understand the general approach, consider the prediction values $F(X)$ that approximate the target $y$ for an arbitrary model $F$. Without putting any constraints on the function $F$, we could choose a differentiable loss function $L(y_{true},y_{pred})$ and define the model that minimizes it:
#
# $$F_* = argmin_{F}L(y,F(X))$$
#
# But since our loss function $L$ is differentiable, we can solve this problem by using iterative gradient descent on an element-wise basis:
#
# $$F_{m+1}(x_i) = F_m(x_i) - \alpha\nabla{L(y_i,F_m(x_i))}$$
#
# There's a clear problem here. All we're doing above is adjusting each predicted $y_i$ value until it gets increasingly close to the true $y_i$, meaning that we're memorizing the training data and overfitting. To not overfit, we have to introduce some constraint that forces generalization. In this case, instead of using the pure gradient, we'll model the gradient at each step with a regression tree $T_{m+1}$, fit on $X$ as features and the individual gradients $-\frac{\partial}{\partial{F_m(x_i)}}L(y_{i},F_m(x_i))$ as targets. Doing this, we can modify the gradient descent update rule so that it becomes:
#
# $$F_{m+1}(x_i) = F_m(x_i) + T_{m+1}(x_i)$$
#
# This looks exactly like the algorithm we used for regression boosting. It seems a bit fancier than what we had earlier, but really the only difference is that we've substituted gradient terms (**pseudo-residuals**) for the simple residuals we had originally. In fact, for SSE regression as above the gradient terms are equal to the residuals, so it's simply a special case of this general version of boosting. And with this single change we've expanded from being able to model least squares regression problems to being able to model for any differentiable loss function.
#
# Here is our generalized algorithm:
#
# 1. Choose loss function $L(y_{true},y_{pred})$
# 2. Initialize with best constant prediction i.e. $F_0 = argmin_{\gamma}\sum\limits_{i=1}^{N}L(y_i,\gamma)$
# 2. For $m = 1,...,k$:
#     1. For $i = 1,...,n$: Set $r_{m-1,i} = -\frac{\partial{L(y_{i},F_{m-1}(x_i))}}{\partial{F_{m-1}(x_i)}}$
#     2. Fit max depth $d$ tree $T_m$ with features $X$, target $r_{m-1}$
#     3. Update $F_m(x) = F_{m-1}(x) + T_m(x)$
#
# Obtain final model: $F(X) = T_0 + T_1(X) + ... + T_k(X)$
#
# Note that we adapt to $k > 2$ class classification problems by training k of these models using [softmax loss](https://www.kdnuggets.com/2016/07/softmax-regression-related-logistic-regression.html).

# %% [markdown]
# ### Pros and Cons of GBMs

# %% [markdown]
# Boosted tree models are often the gold standard for tabular data in modern machine learning. They are well-equipped to model complex ground-truth functions without overfitting, adapt to your loss function of choice, and scale well to large datasets. They tend to do quite well with messy data: tree methods handle missing values naturally and can filter out the least useful input variables based on feature selection for splitting. That said, they are usually more sensitive to hyperparameter choice than random forests and can be a bit tricky and time-consuming to tune. They also lack the explicit interpretability of simpler models like linear/logistic regression.
#
# In short, GBMs are a powerful tool to apply to a wide range of datasets (in terms of loss objective, size, variable types, and messiness). They are probably the closest thing to a catch-all and out-of-the-box modeling approach that currently exists. In a use case where you have at least a reasonable amount of data, want an optimally predictive model, can sacrifice some interpretability, and have the time/resources to tune multiple hyperparameters, you should definitely try a GBM model.
#
# ![](images/xgbcalm.png)
#
# **Summary**
#
# **Pros**:
#
# * Adaptable to wide range of problem settings (regression, classification, unusual or custom loss functions)
# * Potential to be highly expressive (model compex, non-linear relationships)...
# * But still flexible enough to accomodate complexity constraints/regularization
#
# *General tree benefits:*
#
# * Feature scale invariant / natural handling of heterogenous features
# * Automatic handling of missing/NA values
# * Automatic feature interaction
# * Robust to input outliers and unhelpful input features (automatic feature selection)
# * Scales well to large datasets
#
# **Cons**:
#
# * Many hyperparameters to tune for full power -- can be time-consuming and cause overfitting if not well-validated
# * Lack clear/clean interpretability
# * Tree methods struggle with extrapolation (can perform poorly on feature values outside of training range)
# * Can struggle with handling categorical variables (especially if large # of categories)

# %% [markdown]
# ### Hands on GBMs and parameter tuning
#
# Now that we've covered some of the theory behind GBMS and their pros and cons, let's turn to a concrete example of training one. We'll use [xgboost](https://github.com/dmlc/xgboost) (extreme gradient boosting), currently the most popular python package when it comes to training production-level boosting models.
#
# Another popular option is Microsoft's [lightgbm](https://github.com/Microsoft/LightGBM) package, which is  faster and sometimes more accurate than xgboost, but typically harder to tune and closer to bleeding edge as software. Sci-kit learn does have an easier to use [gbm implementation](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html), but it's less efficient and less powerful.
#
# Xgboost makes some adjustments to the algorithm described above and introduces a number of powerful efficiencies that allow the package to scale well. [This post](https://medium.com/@Synced/tree-boosting-with-xgboost-why-does-xgboost-win-every-machine-learning-competition-ca8034c0b283) is a good overview comparison of classic gradient boosting and xgboost, and the [xgboost paper](https://arxiv.org/pdf/1603.02754.pdf) digs into methodology and implementation details.
#
# For this example we'll use the California housing dataset that we've seen before (regression on housing prices). We'll first look at a couple of benchmarks, then step through the process of tuning an xgboost model and see what it can do. The process would be essentially the same for a classification problem (part of what makes boosting so great), which we'll see in a quick example at the end on the Wisconsin breast cancer dataset.

# %%
housing_dataset = california_housing.fetch_california_housing()
X = pd.DataFrame(housing_dataset.data)
X.columns = housing_dataset.feature_names
y = housing_dataset.target

# %%
X.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# 25%        2.429741     33.930000   -121.800000
# 50%        2.818116     34.260000   -118.490000
# 75%        3.282261     37.710000   -118.010000
# max     1243.333333     41.950000   -114.310000

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

#Split data into 3: 60% train, 20% validation, 20% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2018)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=2019)

#Evaluate models with Root Mean Squared Error
def rmse(actuals, preds):
    return np.sqrt(((actuals - preds) ** 2).mean())

# %% [markdown]
# Linear regression benchmark:

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
rmse(lr.predict(X_test), y_test)
# Out:
# 0.7308026104606065

# %% [markdown]
# Random forest benchmark:

# %%
rf = RandomForestRegressor(n_estimators = 100, max_features = 3, n_jobs=-1)
rf.fit(X_train,y_train)
rmse(rf.predict(X_test), y_test)
# Out:
# 0.5074122963520051

# %% [markdown]
# **Xgboost Tuning**
#
# Now that we've set a solid baseline, let's turn to xgboost. Most of the parameters we'll use here should be familiar from the first section of this notebook or similar to what we've seen for random forests, with the exception of *learning rate*.
#
# **n_estimators**: number of base learner trees
# **max_depth**: max depth per base tree (typical values are 3-12)
# **learning_rate**: shrinkage factor applied to each base tree update
# **subsample**: row subsampling rate (similar to RF)
# **min_child_weight**: roughly the minimum allowable child samples for a tree split to occur
# **colsample_bytree**: feature subsampling rate (similar to RF)
#
# The use of a learning rate/shrinkage factor is a form of regularization that can greatly reduce overfitting. It typically trades off with the n_estimators and depth parameters (raising these add complexity) -- lower learning rate  usually wants higher n_estimators, higher max depth usually wants lower learning rate etc. The two subsampling parameters and min_child_weight are also forms of regularization. These types of tradeoffs are part of why it typically works better to follow a manual tuning procedure than to try a massive grid search across different parameter combinations. That simply doesn't scale well to large datasets.
#
# Instead of trying to pick n_estimators by hand or do an intensive grid search, we'll use the **early stopping** technique as a massive time saver. This means that we track our validation error at each update step in the training process, and halt training once validation error hasn't improved in some number of **early_stopping_rounds**. This way, we can set n_estimators to a very large number and simply train until we land at a good stopping point for validation error.
#
# (One technical problem with early stopping is that n_estimators selection can overfit to the validation data. One reasonable solution is to combine early stopping with k-fold cross validation, and use the average n_estimators across k training rounds for training a new model).
#
# Here is our first xgboost example:

# %%
gbm = xgb.XGBRegressor( 
                       n_estimators=30000, #arbitrary large number
                       max_depth=3,
                       objective="reg:linear",
                       learning_rate=.1, 
                       subsample=1,
                       min_child_weight=1,
                       colsample_bytree=.8
                      )

eval_set=[(X_train,y_train),(X_val,y_val)] #tracking train/validation error as we go
fit_model = gbm.fit( 
                    X_train, y_train, 
                    eval_set=eval_set,
                    eval_metric='rmse',
                    early_stopping_rounds=20,
                    verbose=True #gives output log as below
                   )
# Out:
# [10:52:07] WARNING: d:\build\xgboost\xgboost-0.90.git\src\objective\regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1.80129	validation_1-rmse:1.80777
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:1.65548	validation_1-rmse:1.66344
# [2]	validation_0-rmse:1.52886	validation_1-rmse:1.53673
# [3]	validation_0-rmse:1.41469	validation_1-rmse:1.42474
# [4]	validation_0-rmse:1.31376	validation_1-rmse:1.32542
# [5]	validation_0-rmse:1.22554	validation_1-rmse:1.2386
# [6]	validation_0-rmse:1.14812	validation_1-rmse:1.1624
# [7]	validation_0-rmse:1.08591	validation_1-rmse:1.10048
# [8]	validation_0-rmse:1.03185	validation_1-rmse:1.04655
# [9]	validation_0-rmse:0.98481	validation_1-rmse:1.00015
# [10]	validation_0-rmse:0.936805	validation_1-rmse:0.953276
# [11]	validation_0-rmse:0.901627	validation_1-rmse:0.917451
# [12]	validation_0-rmse:0.864715	validation_1-rmse:0.881416
# [13]	validation_0-rmse:0.833485	validation_1-rmse:0.851635
# [14]	validation_0-rmse:0.805916	validation_1-rmse:0.825188
# [15]	validation_0-rmse:0.775887	validation_1-rmse:0.795437
# [16]	validation_0-rmse:0.754777	validation_1-rmse:0.775752
# [17]	validation_0-rmse:0.736145	validation_1-rmse:0.757263
# [18]	validation_0-rmse:0.720122	validation_1-rmse:0.74165
# [19]	validation_0-rmse:0.703004	validation_1-rmse:0.725182
# [20]	validation_0-rmse:0.690666	validation_1-rmse:0.712393
# [21]	validation_0-rmse:0.679787	validation_1-rmse:0.702207
# [22]	validation_0-rmse:0.67047	validation_1-rmse:0.69349
# [23]	validation_0-rmse:0.656176	validation_1-rmse:0.67947
# [24]	validation_0-rmse:0.643259	validation_1-rmse:0.665781
# [25]	validation_0-rmse:0.636636	validation_1-rmse:0.65889
# [26]	validation_0-rmse:0.626522	validation_1-rmse:0.647975
# [27]	validation_0-rmse:0.620478	validation_1-rmse:0.641831
# [28]	validation_0-rmse:0.615454	validation_1-rmse:0.636743
# [29]	validation_0-rmse:0.610006	validation_1-rmse:0.630977
# [30]	validation_0-rmse:0.606382	validation_1-rmse:0.627509
# [31]	validation_0-rmse:0.602588	validation_1-rmse:0.624113
# [32]	validation_0-rmse:0.599323	validation_1-rmse:0.621047
# [33]	validation_0-rmse:0.592834	validation_1-rmse:0.61471
# [34]	validation_0-rmse:0.590158	validation_1-rmse:0.611952
# [35]	validation_0-rmse:0.587985	validation_1-rmse:0.609516
# [36]	validation_0-rmse:0.585289	validation_1-rmse:0.606571
# [37]	validation_0-rmse:0.579687	validation_1-rmse:0.600826
# [38]	validation_0-rmse:0.574807	validation_1-rmse:0.596105
# [39]	validation_0-rmse:0.570873	validation_1-rmse:0.592254
# [40]	validation_0-rmse:0.566893	validation_1-rmse:0.588133
# [41]	validation_0-rmse:0.565036	validation_1-rmse:0.586398
# [42]	validation_0-rmse:0.563438	validation_1-rmse:0.585236
# [43]	validation_0-rmse:0.561881	validation_1-rmse:0.58401
# [44]	validation_0-rmse:0.558827	validation_1-rmse:0.581054
# [45]	validation_0-rmse:0.555475	validation_1-rmse:0.577822
# [46]	validation_0-rmse:0.554048	validation_1-rmse:0.576401
# [47]	validation_0-rmse:0.55271	validation_1-rmse:0.57542
# [48]	validation_0-rmse:0.551013	validation_1-rmse:0.573973
# [49]	validation_0-rmse:0.549189	validation_1-rmse:0.572244
# [50]	validation_0-rmse:0.546832	validation_1-rmse:0.569952
# [51]	validation_0-rmse:0.543983	validation_1-rmse:0.567023
# [52]	validation_0-rmse:0.543072	validation_1-rmse:0.566526
# [53]	validation_0-rmse:0.542023	validation_1-rmse:0.565868
# [54]	validation_0-rmse:0.540878	validation_1-rmse:0.564923
# [55]	validation_0-rmse:0.538855	validation_1-rmse:0.56319
# [56]	validation_0-rmse:0.537854	validation_1-rmse:0.562858
# [57]	validation_0-rmse:0.537042	validation_1-rmse:0.562557
# [58]	validation_0-rmse:0.534975	validation_1-rmse:0.560494
# [59]	validation_0-rmse:0.534289	validation_1-rmse:0.560121
# [60]	validation_0-rmse:0.533419	validation_1-rmse:0.559661
# [61]	validation_0-rmse:0.53115	validation_1-rmse:0.557346
# [62]	validation_0-rmse:0.530047	validation_1-rmse:0.556356
# [63]	validation_0-rmse:0.527916	validation_1-rmse:0.554131
# [64]	validation_0-rmse:0.527268	validation_1-rmse:0.553592
# [65]	validation_0-rmse:0.526655	validation_1-rmse:0.553297
# [66]	validation_0-rmse:0.526015	validation_1-rmse:0.553037
# [67]	validation_0-rmse:0.525138	validation_1-rmse:0.552314
# [68]	validation_0-rmse:0.524629	validation_1-rmse:0.552372
# [69]	validation_0-rmse:0.523119	validation_1-rmse:0.550958
# [117]	validation_0-rmse:0.491725	validation_1-rmse:0.529071
# [118]	validation_0-rmse:0.491146	validation_1-rmse:0.528583
# [119]	validation_0-rmse:0.490401	validation_1-rmse:0.528
# [120]	validation_0-rmse:0.489808	validation_1-rmse:0.527428
# [121]	validation_0-rmse:0.48835	validation_1-rmse:0.526136
# [122]	validation_0-rmse:0.487669	validation_1-rmse:0.525909
# [123]	validation_0-rmse:0.48745	validation_1-rmse:0.525748
# [124]	validation_0-rmse:0.487319	validation_1-rmse:0.525723
# [125]	validation_0-rmse:0.487003	validation_1-rmse:0.525524
# [126]	validation_0-rmse:0.48648	validation_1-rmse:0.52523
# [127]	validation_0-rmse:0.486392	validation_1-rmse:0.525206
# [128]	validation_0-rmse:0.485788	validation_1-rmse:0.524836
# [129]	validation_0-rmse:0.485228	validation_1-rmse:0.524712
# [130]	validation_0-rmse:0.484667	validation_1-rmse:0.524524
# [131]	validation_0-rmse:0.484467	validation_1-rmse:0.524448
# [132]	validation_0-rmse:0.484241	validation_1-rmse:0.524438
# [133]	validation_0-rmse:0.483717	validation_1-rmse:0.524226
# [134]	validation_0-rmse:0.483535	validation_1-rmse:0.52414
# [135]	validation_0-rmse:0.483261	validation_1-rmse:0.523978
# [136]	validation_0-rmse:0.4826	validation_1-rmse:0.523453
# [137]	validation_0-rmse:0.482156	validation_1-rmse:0.523427
# [138]	validation_0-rmse:0.48157	validation_1-rmse:0.52315
# [139]	validation_0-rmse:0.481386	validation_1-rmse:0.52299
# [140]	validation_0-rmse:0.481212	validation_1-rmse:0.523108
# [141]	validation_0-rmse:0.480111	validation_1-rmse:0.5221
# [142]	validation_0-rmse:0.479609	validation_1-rmse:0.521595
# [143]	validation_0-rmse:0.479343	validation_1-rmse:0.52136
# [144]	validation_0-rmse:0.478965	validation_1-rmse:0.52102
# [145]	validation_0-rmse:0.47884	validation_1-rmse:0.521095
# [146]	validation_0-rmse:0.478446	validation_1-rmse:0.521067
# [147]	validation_0-rmse:0.478254	validation_1-rmse:0.521084
# [148]	validation_0-rmse:0.477904	validation_1-rmse:0.520833
# [149]	validation_0-rmse:0.4771	validation_1-rmse:0.520066
# [150]	validation_0-rmse:0.476771	validation_1-rmse:0.519869
# [151]	validation_0-rmse:0.476403	validation_1-rmse:0.51976
# [152]	validation_0-rmse:0.476059	validation_1-rmse:0.519463
# [153]	validation_0-rmse:0.475923	validation_1-rmse:0.519466
# [154]	validation_0-rmse:0.475634	validation_1-rmse:0.519144
# [155]	validation_0-rmse:0.475158	validation_1-rmse:0.518726
# [156]	validation_0-rmse:0.474727	validation_1-rmse:0.518281
# [157]	validation_0-rmse:0.474416	validation_1-rmse:0.518134
# [158]	validation_0-rmse:0.474272	validation_1-rmse:0.518087
# [159]	validation_0-rmse:0.473229	validation_1-rmse:0.516951
# [160]	validation_0-rmse:0.472753	validation_1-rmse:0.51668
# [161]	validation_0-rmse:0.472168	validation_1-rmse:0.516305
# [162]	validation_0-rmse:0.471533	validation_1-rmse:0.515698
# [163]	validation_0-rmse:0.471379	validation_1-rmse:0.515481
# [164]	validation_0-rmse:0.47091	validation_1-rmse:0.515632
# [306]	validation_0-rmse:0.433018	validation_1-rmse:0.496062
# [307]	validation_0-rmse:0.432787	validation_1-rmse:0.496102
# [308]	validation_0-rmse:0.432612	validation_1-rmse:0.496055
# [309]	validation_0-rmse:0.432351	validation_1-rmse:0.495869
# [310]	validation_0-rmse:0.432162	validation_1-rmse:0.495857
# [311]	validation_0-rmse:0.432003	validation_1-rmse:0.495863
# [312]	validation_0-rmse:0.431739	validation_1-rmse:0.495904
# [313]	validation_0-rmse:0.431404	validation_1-rmse:0.495815
# [314]	validation_0-rmse:0.431154	validation_1-rmse:0.495655
# [315]	validation_0-rmse:0.431013	validation_1-rmse:0.495637
# [316]	validation_0-rmse:0.430652	validation_1-rmse:0.495225
# [317]	validation_0-rmse:0.430318	validation_1-rmse:0.494937
# [318]	validation_0-rmse:0.430177	validation_1-rmse:0.494935
# [319]	validation_0-rmse:0.430016	validation_1-rmse:0.494953
# [320]	validation_0-rmse:0.429681	validation_1-rmse:0.494797
# [321]	validation_0-rmse:0.429509	validation_1-rmse:0.494618
# [322]	validation_0-rmse:0.429314	validation_1-rmse:0.494489
# [323]	validation_0-rmse:0.429181	validation_1-rmse:0.494556
# [324]	validation_0-rmse:0.429027	validation_1-rmse:0.494421
# [325]	validation_0-rmse:0.428914	validation_1-rmse:0.494359
# [326]	validation_0-rmse:0.428726	validation_1-rmse:0.494311
# [327]	validation_0-rmse:0.428657	validation_1-rmse:0.494333
# [328]	validation_0-rmse:0.428446	validation_1-rmse:0.494245
# [329]	validation_0-rmse:0.428209	validation_1-rmse:0.494238
# [330]	validation_0-rmse:0.427998	validation_1-rmse:0.494083
# [331]	validation_0-rmse:0.427814	validation_1-rmse:0.494093
# [332]	validation_0-rmse:0.427726	validation_1-rmse:0.49411
# [333]	validation_0-rmse:0.427584	validation_1-rmse:0.494106
# [334]	validation_0-rmse:0.427403	validation_1-rmse:0.494121
# [335]	validation_0-rmse:0.427264	validation_1-rmse:0.49411
# [336]	validation_0-rmse:0.427117	validation_1-rmse:0.494
# [337]	validation_0-rmse:0.42699	validation_1-rmse:0.494036
# [338]	validation_0-rmse:0.426878	validation_1-rmse:0.494024
# [339]	validation_0-rmse:0.426752	validation_1-rmse:0.49397
# [340]	validation_0-rmse:0.426589	validation_1-rmse:0.4939
# [341]	validation_0-rmse:0.426305	validation_1-rmse:0.493729
# [342]	validation_0-rmse:0.426176	validation_1-rmse:0.493741
# [343]	validation_0-rmse:0.426002	validation_1-rmse:0.493745
# [344]	validation_0-rmse:0.425785	validation_1-rmse:0.493697
# [345]	validation_0-rmse:0.42572	validation_1-rmse:0.493645
# [346]	validation_0-rmse:0.425616	validation_1-rmse:0.49364
# [347]	validation_0-rmse:0.425337	validation_1-rmse:0.493623
# [348]	validation_0-rmse:0.425165	validation_1-rmse:0.493472
# [349]	validation_0-rmse:0.424774	validation_1-rmse:0.493122
# [350]	validation_0-rmse:0.424527	validation_1-rmse:0.493067
# [351]	validation_0-rmse:0.424362	validation_1-rmse:0.492933
# [352]	validation_0-rmse:0.42423	validation_1-rmse:0.492875
# [353]	validation_0-rmse:0.424141	validation_1-rmse:0.492816
# [354]	validation_0-rmse:0.423956	validation_1-rmse:0.492767
# [355]	validation_0-rmse:0.423778	validation_1-rmse:0.492706
# [356]	validation_0-rmse:0.423595	validation_1-rmse:0.492689
# [357]	validation_0-rmse:0.423369	validation_1-rmse:0.49255
# [358]	validation_0-rmse:0.423176	validation_1-rmse:0.492346
# [359]	validation_0-rmse:0.423016	validation_1-rmse:0.492277
# [360]	validation_0-rmse:0.422812	validation_1-rmse:0.492266
# [361]	validation_0-rmse:0.422602	validation_1-rmse:0.492034
# [362]	validation_0-rmse:0.422543	validation_1-rmse:0.492091
# [363]	validation_0-rmse:0.42242	validation_1-rmse:0.492116
# [364]	validation_0-rmse:0.422371	validation_1-rmse:0.492136
# [365]	validation_0-rmse:0.42228	validation_1-rmse:0.492098
# [366]	validation_0-rmse:0.422212	validation_1-rmse:0.492135
# [367]	validation_0-rmse:0.422084	validation_1-rmse:0.491977
# [368]	validation_0-rmse:0.421825	validation_1-rmse:0.491917
# [369]	validation_0-rmse:0.42167	validation_1-rmse:0.491894
# [370]	validation_0-rmse:0.421559	validation_1-rmse:0.491917
# [371]	validation_0-rmse:0.421346	validation_1-rmse:0.491826
# [372]	validation_0-rmse:0.421031	validation_1-rmse:0.491506
# [373]	validation_0-rmse:0.420932	validation_1-rmse:0.49156
# [374]	validation_0-rmse:0.420741	validation_1-rmse:0.49146
# [375]	validation_0-rmse:0.42054	validation_1-rmse:0.491375
# [376]	validation_0-rmse:0.420377	validation_1-rmse:0.491296
# [377]	validation_0-rmse:0.420163	validation_1-rmse:0.491052
# [378]	validation_0-rmse:0.419992	validation_1-rmse:0.491014
# [379]	validation_0-rmse:0.419837	validation_1-rmse:0.491047
# [380]	validation_0-rmse:0.419665	validation_1-rmse:0.490976
# [381]	validation_0-rmse:0.419523	validation_1-rmse:0.490903
# [382]	validation_0-rmse:0.419403	validation_1-rmse:0.49082
# [383]	validation_0-rmse:0.419289	validation_1-rmse:0.490839
# [384]	validation_0-rmse:0.419181	validation_1-rmse:0.490901
# [385]	validation_0-rmse:0.419038	validation_1-rmse:0.490778
# [386]	validation_0-rmse:0.418916	validation_1-rmse:0.490747
# [387]	validation_0-rmse:0.418682	validation_1-rmse:0.490578
# [388]	validation_0-rmse:0.418565	validation_1-rmse:0.490574
# [389]	validation_0-rmse:0.418337	validation_1-rmse:0.490331
# [390]	validation_0-rmse:0.418203	validation_1-rmse:0.490348
# [391]	validation_0-rmse:0.417965	validation_1-rmse:0.490206
# [392]	validation_0-rmse:0.41782	validation_1-rmse:0.490049
# [393]	validation_0-rmse:0.417666	validation_1-rmse:0.489938
# [394]	validation_0-rmse:0.417497	validation_1-rmse:0.489679
# [395]	validation_0-rmse:0.417316	validation_1-rmse:0.489618
# [396]	validation_0-rmse:0.417185	validation_1-rmse:0.489567
# [397]	validation_0-rmse:0.417079	validation_1-rmse:0.489525
# [398]	validation_0-rmse:0.417012	validation_1-rmse:0.489558
# [399]	validation_0-rmse:0.416933	validation_1-rmse:0.489557
# [400]	validation_0-rmse:0.416834	validation_1-rmse:0.489452
# [448]	validation_0-rmse:0.408978	validation_1-rmse:0.486725
# [449]	validation_0-rmse:0.408892	validation_1-rmse:0.486695
# [450]	validation_0-rmse:0.408827	validation_1-rmse:0.486715
# [451]	validation_0-rmse:0.408722	validation_1-rmse:0.486746
# [452]	validation_0-rmse:0.408584	validation_1-rmse:0.486792
# [453]	validation_0-rmse:0.408337	validation_1-rmse:0.486818
# [454]	validation_0-rmse:0.408187	validation_1-rmse:0.486652
# [455]	validation_0-rmse:0.408098	validation_1-rmse:0.486609
# [456]	validation_0-rmse:0.407964	validation_1-rmse:0.486661
# [457]	validation_0-rmse:0.407855	validation_1-rmse:0.486618
# [458]	validation_0-rmse:0.407781	validation_1-rmse:0.486701
# [459]	validation_0-rmse:0.407708	validation_1-rmse:0.486637
# [460]	validation_0-rmse:0.407588	validation_1-rmse:0.48666
# [461]	validation_0-rmse:0.407505	validation_1-rmse:0.48664
# [462]	validation_0-rmse:0.407347	validation_1-rmse:0.486604
# [463]	validation_0-rmse:0.407244	validation_1-rmse:0.486541
# [464]	validation_0-rmse:0.407085	validation_1-rmse:0.486528
# [465]	validation_0-rmse:0.406937	validation_1-rmse:0.486563
# [466]	validation_0-rmse:0.40674	validation_1-rmse:0.486387
# [467]	validation_0-rmse:0.406584	validation_1-rmse:0.486359
# [468]	validation_0-rmse:0.406458	validation_1-rmse:0.486355
# [469]	validation_0-rmse:0.406182	validation_1-rmse:0.486129
# [470]	validation_0-rmse:0.406029	validation_1-rmse:0.486071
# [471]	validation_0-rmse:0.405973	validation_1-rmse:0.486056
# [472]	validation_0-rmse:0.405858	validation_1-rmse:0.486068
# [473]	validation_0-rmse:0.405722	validation_1-rmse:0.486007
# [474]	validation_0-rmse:0.405465	validation_1-rmse:0.485968
# [475]	validation_0-rmse:0.405256	validation_1-rmse:0.486016
# [476]	validation_0-rmse:0.4051	validation_1-rmse:0.485998
# [477]	validation_0-rmse:0.404989	validation_1-rmse:0.485962
# [478]	validation_0-rmse:0.404747	validation_1-rmse:0.485673
# [479]	validation_0-rmse:0.404592	validation_1-rmse:0.485605
# [480]	validation_0-rmse:0.404436	validation_1-rmse:0.485699
# [481]	validation_0-rmse:0.404361	validation_1-rmse:0.485675
# [482]	validation_0-rmse:0.404255	validation_1-rmse:0.485658
# [483]	validation_0-rmse:0.404125	validation_1-rmse:0.485564
# [484]	validation_0-rmse:0.403919	validation_1-rmse:0.485416
# [485]	validation_0-rmse:0.403816	validation_1-rmse:0.485473
# [486]	validation_0-rmse:0.403641	validation_1-rmse:0.485471
# [487]	validation_0-rmse:0.403528	validation_1-rmse:0.485399
# [488]	validation_0-rmse:0.403405	validation_1-rmse:0.485372
# [489]	validation_0-rmse:0.403326	validation_1-rmse:0.485341
# [490]	validation_0-rmse:0.403185	validation_1-rmse:0.485262
# [491]	validation_0-rmse:0.40299	validation_1-rmse:0.485313
# [492]	validation_0-rmse:0.402825	validation_1-rmse:0.485396
# [493]	validation_0-rmse:0.402653	validation_1-rmse:0.485447
# [494]	validation_0-rmse:0.402504	validation_1-rmse:0.485447
# [495]	validation_0-rmse:0.402407	validation_1-rmse:0.485378
# [496]	validation_0-rmse:0.402282	validation_1-rmse:0.48536
# [497]	validation_0-rmse:0.402117	validation_1-rmse:0.485416
# [498]	validation_0-rmse:0.402028	validation_1-rmse:0.485456
# [499]	validation_0-rmse:0.401909	validation_1-rmse:0.485406
# [500]	validation_0-rmse:0.401683	validation_1-rmse:0.485296
# [501]	validation_0-rmse:0.401563	validation_1-rmse:0.485271
# [502]	validation_0-rmse:0.401463	validation_1-rmse:0.485252
# [503]	validation_0-rmse:0.401353	validation_1-rmse:0.485119
# [504]	validation_0-rmse:0.401239	validation_1-rmse:0.485063
# [505]	validation_0-rmse:0.401094	validation_1-rmse:0.485047
# [506]	validation_0-rmse:0.400769	validation_1-rmse:0.484761
# [507]	validation_0-rmse:0.400707	validation_1-rmse:0.484649
# [508]	validation_0-rmse:0.400591	validation_1-rmse:0.484649
# [509]	validation_0-rmse:0.400507	validation_1-rmse:0.484601
# [510]	validation_0-rmse:0.400354	validation_1-rmse:0.484621
# [511]	validation_0-rmse:0.400138	validation_1-rmse:0.484562
# [512]	validation_0-rmse:0.400018	validation_1-rmse:0.484718
# [513]	validation_0-rmse:0.399947	validation_1-rmse:0.484693
# [514]	validation_0-rmse:0.399864	validation_1-rmse:0.484694
# [515]	validation_0-rmse:0.399617	validation_1-rmse:0.484491
# [516]	validation_0-rmse:0.399488	validation_1-rmse:0.484469
# [517]	validation_0-rmse:0.399342	validation_1-rmse:0.484397
# [518]	validation_0-rmse:0.399223	validation_1-rmse:0.484351
# [519]	validation_0-rmse:0.399066	validation_1-rmse:0.48423
# [520]	validation_0-rmse:0.399009	validation_1-rmse:0.484198
# [521]	validation_0-rmse:0.398667	validation_1-rmse:0.483897
# [522]	validation_0-rmse:0.398496	validation_1-rmse:0.483885
# [523]	validation_0-rmse:0.398287	validation_1-rmse:0.483791
# [524]	validation_0-rmse:0.39821	validation_1-rmse:0.483761
# [525]	validation_0-rmse:0.39806	validation_1-rmse:0.483775
# [526]	validation_0-rmse:0.397976	validation_1-rmse:0.483853
# [527]	validation_0-rmse:0.397894	validation_1-rmse:0.48379
# [528]	validation_0-rmse:0.397763	validation_1-rmse:0.483794
# [529]	validation_0-rmse:0.397631	validation_1-rmse:0.483792
# [530]	validation_0-rmse:0.397449	validation_1-rmse:0.483641
# [531]	validation_0-rmse:0.39728	validation_1-rmse:0.483507
# [532]	validation_0-rmse:0.397131	validation_1-rmse:0.483609
# [533]	validation_0-rmse:0.397029	validation_1-rmse:0.48358
# [534]	validation_0-rmse:0.396912	validation_1-rmse:0.483519
# [535]	validation_0-rmse:0.396713	validation_1-rmse:0.48339
# [536]	validation_0-rmse:0.39662	validation_1-rmse:0.48336
# [537]	validation_0-rmse:0.396435	validation_1-rmse:0.483284
# [538]	validation_0-rmse:0.396331	validation_1-rmse:0.483299
# [539]	validation_0-rmse:0.396237	validation_1-rmse:0.48329
# [540]	validation_0-rmse:0.396135	validation_1-rmse:0.483242
# [541]	validation_0-rmse:0.396053	validation_1-rmse:0.483251
# [542]	validation_0-rmse:0.395823	validation_1-rmse:0.483051
# [543]	validation_0-rmse:0.395788	validation_1-rmse:0.483072
# [544]	validation_0-rmse:0.39569	validation_1-rmse:0.483084
# [545]	validation_0-rmse:0.395557	validation_1-rmse:0.482992
# [546]	validation_0-rmse:0.395482	validation_1-rmse:0.482986
# [547]	validation_0-rmse:0.39539	validation_1-rmse:0.482889
# [548]	validation_0-rmse:0.395297	validation_1-rmse:0.48286
# [549]	validation_0-rmse:0.395164	validation_1-rmse:0.482892
# [550]	validation_0-rmse:0.395027	validation_1-rmse:0.482882
# [551]	validation_0-rmse:0.394904	validation_1-rmse:0.482835
# [552]	validation_0-rmse:0.394813	validation_1-rmse:0.482874
# [553]	validation_0-rmse:0.39473	validation_1-rmse:0.482861
# [554]	validation_0-rmse:0.394557	validation_1-rmse:0.482622
# [555]	validation_0-rmse:0.394433	validation_1-rmse:0.482632
# [556]	validation_0-rmse:0.3943	validation_1-rmse:0.482664
# [557]	validation_0-rmse:0.394127	validation_1-rmse:0.482513
# [558]	validation_0-rmse:0.39404	validation_1-rmse:0.48255
# [559]	validation_0-rmse:0.393897	validation_1-rmse:0.482586
# [560]	validation_0-rmse:0.393779	validation_1-rmse:0.482501
# [561]	validation_0-rmse:0.393647	validation_1-rmse:0.48257
# [562]	validation_0-rmse:0.393544	validation_1-rmse:0.482634
# [563]	validation_0-rmse:0.393459	validation_1-rmse:0.482635
# [564]	validation_0-rmse:0.393367	validation_1-rmse:0.482645
# [565]	validation_0-rmse:0.393326	validation_1-rmse:0.482611
# [566]	validation_0-rmse:0.393216	validation_1-rmse:0.482595
# [567]	validation_0-rmse:0.393137	validation_1-rmse:0.482594
# [568]	validation_0-rmse:0.393025	validation_1-rmse:0.482564
# [569]	validation_0-rmse:0.392784	validation_1-rmse:0.482596
# [570]	validation_0-rmse:0.392701	validation_1-rmse:0.482487
# [571]	validation_0-rmse:0.392596	validation_1-rmse:0.482353
# [572]	validation_0-rmse:0.392542	validation_1-rmse:0.482341
# [573]	validation_0-rmse:0.392466	validation_1-rmse:0.482319
# [574]	validation_0-rmse:0.392326	validation_1-rmse:0.482262
# [575]	validation_0-rmse:0.392255	validation_1-rmse:0.4822
# [576]	validation_0-rmse:0.392137	validation_1-rmse:0.48224
# [577]	validation_0-rmse:0.392092	validation_1-rmse:0.482257
# [578]	validation_0-rmse:0.391935	validation_1-rmse:0.482155
# [579]	validation_0-rmse:0.391859	validation_1-rmse:0.482195
# [580]	validation_0-rmse:0.391832	validation_1-rmse:0.482239
# [581]	validation_0-rmse:0.391713	validation_1-rmse:0.482313
# [582]	validation_0-rmse:0.391684	validation_1-rmse:0.482355
# [583]	validation_0-rmse:0.391596	validation_1-rmse:0.48233
# [584]	validation_0-rmse:0.391475	validation_1-rmse:0.48231
# [585]	validation_0-rmse:0.391378	validation_1-rmse:0.482317
# [586]	validation_0-rmse:0.391252	validation_1-rmse:0.482244
# [587]	validation_0-rmse:0.391142	validation_1-rmse:0.482249
# [588]	validation_0-rmse:0.391019	validation_1-rmse:0.482228
# [589]	validation_0-rmse:0.39091	validation_1-rmse:0.482216
# [590]	validation_0-rmse:0.390764	validation_1-rmse:0.48218
# [591]	validation_0-rmse:0.390651	validation_1-rmse:0.48205
# [592]	validation_0-rmse:0.390474	validation_1-rmse:0.482086
# [593]	validation_0-rmse:0.390423	validation_1-rmse:0.482118
# [594]	validation_0-rmse:0.390237	validation_1-rmse:0.482058
# [595]	validation_0-rmse:0.39009	validation_1-rmse:0.481992
# [596]	validation_0-rmse:0.389786	validation_1-rmse:0.481818
# [597]	validation_0-rmse:0.389636	validation_1-rmse:0.481672
# [598]	validation_0-rmse:0.389528	validation_1-rmse:0.481653
# [599]	validation_0-rmse:0.389463	validation_1-rmse:0.481613
# [600]	validation_0-rmse:0.389386	validation_1-rmse:0.48157
# [601]	validation_0-rmse:0.389243	validation_1-rmse:0.481561
# [602]	validation_0-rmse:0.389161	validation_1-rmse:0.481616
# [603]	validation_0-rmse:0.389068	validation_1-rmse:0.481582
# [604]	validation_0-rmse:0.388862	validation_1-rmse:0.481424
# [605]	validation_0-rmse:0.388833	validation_1-rmse:0.481445
# [606]	validation_0-rmse:0.388755	validation_1-rmse:0.481425
# [607]	validation_0-rmse:0.388637	validation_1-rmse:0.481407
# [608]	validation_0-rmse:0.388509	validation_1-rmse:0.481397
# [609]	validation_0-rmse:0.388386	validation_1-rmse:0.481379
# [610]	validation_0-rmse:0.3882	validation_1-rmse:0.481338
# [611]	validation_0-rmse:0.388129	validation_1-rmse:0.48142
# [612]	validation_0-rmse:0.387983	validation_1-rmse:0.481366
# [613]	validation_0-rmse:0.387858	validation_1-rmse:0.481314
# [614]	validation_0-rmse:0.387822	validation_1-rmse:0.481306
# [615]	validation_0-rmse:0.387801	validation_1-rmse:0.481337
# [616]	validation_0-rmse:0.387628	validation_1-rmse:0.481106
# [617]	validation_0-rmse:0.387527	validation_1-rmse:0.481118
# [618]	validation_0-rmse:0.387414	validation_1-rmse:0.481061
# [619]	validation_0-rmse:0.387326	validation_1-rmse:0.481049
# [620]	validation_0-rmse:0.387247	validation_1-rmse:0.481088
# [621]	validation_0-rmse:0.387222	validation_1-rmse:0.481104
# [622]	validation_0-rmse:0.387147	validation_1-rmse:0.481048
# [623]	validation_0-rmse:0.387022	validation_1-rmse:0.481009
# [624]	validation_0-rmse:0.386895	validation_1-rmse:0.481101
# [625]	validation_0-rmse:0.386775	validation_1-rmse:0.481073
# [626]	validation_0-rmse:0.386637	validation_1-rmse:0.481056
# [627]	validation_0-rmse:0.38656	validation_1-rmse:0.481026
# [628]	validation_0-rmse:0.386511	validation_1-rmse:0.480972
# [629]	validation_0-rmse:0.386388	validation_1-rmse:0.480985
# [630]	validation_0-rmse:0.386099	validation_1-rmse:0.480826
# [631]	validation_0-rmse:0.385975	validation_1-rmse:0.480791
# [632]	validation_0-rmse:0.385881	validation_1-rmse:0.48081
# [633]	validation_0-rmse:0.385726	validation_1-rmse:0.48081
# [634]	validation_0-rmse:0.38558	validation_1-rmse:0.480568
# [635]	validation_0-rmse:0.385479	validation_1-rmse:0.480582
# [636]	validation_0-rmse:0.385367	validation_1-rmse:0.480572
# [637]	validation_0-rmse:0.385287	validation_1-rmse:0.480536
# [638]	validation_0-rmse:0.385134	validation_1-rmse:0.480646
# [639]	validation_0-rmse:0.385035	validation_1-rmse:0.480724
# [640]	validation_0-rmse:0.384922	validation_1-rmse:0.480686
# [641]	validation_0-rmse:0.384847	validation_1-rmse:0.480617
# [642]	validation_0-rmse:0.384745	validation_1-rmse:0.48062
# [643]	validation_0-rmse:0.384502	validation_1-rmse:0.480521
# [644]	validation_0-rmse:0.384474	validation_1-rmse:0.480477
# [645]	validation_0-rmse:0.384455	validation_1-rmse:0.480534
# [646]	validation_0-rmse:0.384391	validation_1-rmse:0.480541
# [647]	validation_0-rmse:0.384272	validation_1-rmse:0.480507
# [648]	validation_0-rmse:0.38416	validation_1-rmse:0.480429
# [649]	validation_0-rmse:0.384036	validation_1-rmse:0.480238
# [650]	validation_0-rmse:0.383931	validation_1-rmse:0.48023
# [651]	validation_0-rmse:0.383815	validation_1-rmse:0.480218
# [652]	validation_0-rmse:0.383727	validation_1-rmse:0.480203
# [653]	validation_0-rmse:0.383587	validation_1-rmse:0.480166
# [654]	validation_0-rmse:0.383531	validation_1-rmse:0.480149
# [655]	validation_0-rmse:0.383468	validation_1-rmse:0.480094
# [656]	validation_0-rmse:0.383389	validation_1-rmse:0.480125
# [657]	validation_0-rmse:0.383351	validation_1-rmse:0.4801
# [658]	validation_0-rmse:0.383185	validation_1-rmse:0.480084
# [659]	validation_0-rmse:0.383127	validation_1-rmse:0.48009
# [660]	validation_0-rmse:0.383045	validation_1-rmse:0.48012
# [661]	validation_0-rmse:0.382895	validation_1-rmse:0.480015
# [662]	validation_0-rmse:0.382793	validation_1-rmse:0.479982
# [663]	validation_0-rmse:0.382645	validation_1-rmse:0.47985
# [664]	validation_0-rmse:0.38258	validation_1-rmse:0.479819
# [665]	validation_0-rmse:0.38247	validation_1-rmse:0.479829
# [666]	validation_0-rmse:0.382379	validation_1-rmse:0.479789
# [667]	validation_0-rmse:0.382323	validation_1-rmse:0.479814
# [668]	validation_0-rmse:0.382191	validation_1-rmse:0.479896
# [669]	validation_0-rmse:0.382118	validation_1-rmse:0.479865
# [670]	validation_0-rmse:0.382017	validation_1-rmse:0.479823
# [671]	validation_0-rmse:0.381927	validation_1-rmse:0.479753
# [672]	validation_0-rmse:0.381801	validation_1-rmse:0.479825
# [673]	validation_0-rmse:0.381738	validation_1-rmse:0.47982
# [674]	validation_0-rmse:0.381604	validation_1-rmse:0.479767
# [675]	validation_0-rmse:0.38145	validation_1-rmse:0.479664
# [676]	validation_0-rmse:0.381392	validation_1-rmse:0.479628
# [677]	validation_0-rmse:0.381232	validation_1-rmse:0.479492
# [678]	validation_0-rmse:0.381092	validation_1-rmse:0.479477
# [679]	validation_0-rmse:0.380773	validation_1-rmse:0.479215
# [680]	validation_0-rmse:0.380614	validation_1-rmse:0.479209
# [681]	validation_0-rmse:0.380512	validation_1-rmse:0.479351
# [682]	validation_0-rmse:0.380415	validation_1-rmse:0.47928
# [683]	validation_0-rmse:0.380312	validation_1-rmse:0.479248
# [684]	validation_0-rmse:0.380173	validation_1-rmse:0.47928
# [685]	validation_0-rmse:0.380054	validation_1-rmse:0.479329
# [686]	validation_0-rmse:0.379919	validation_1-rmse:0.479352
# [687]	validation_0-rmse:0.379803	validation_1-rmse:0.479357
# [688]	validation_0-rmse:0.379708	validation_1-rmse:0.479375
# [689]	validation_0-rmse:0.379667	validation_1-rmse:0.479369
# [690]	validation_0-rmse:0.379584	validation_1-rmse:0.479378
# [691]	validation_0-rmse:0.379537	validation_1-rmse:0.479418
# [692]	validation_0-rmse:0.379481	validation_1-rmse:0.479426
# [693]	validation_0-rmse:0.379344	validation_1-rmse:0.47942
# [694]	validation_0-rmse:0.379214	validation_1-rmse:0.479398
# [695]	validation_0-rmse:0.379164	validation_1-rmse:0.479398
# [696]	validation_0-rmse:0.378991	validation_1-rmse:0.479379
# [697]	validation_0-rmse:0.378933	validation_1-rmse:0.479345
# [698]	validation_0-rmse:0.378775	validation_1-rmse:0.47937
# [699]	validation_0-rmse:0.378663	validation_1-rmse:0.479349
# [700]	validation_0-rmse:0.378559	validation_1-rmse:0.479294
# Stopping. Best iteration:
# [680]	validation_0-rmse:0.380614	validation_1-rmse:0.479209

# %% [markdown]
# Starting xgb benchmark: we've already improved on RF.

# %%
# predict using n_estimators with lowest validation error
rmse(gbm.predict(X_test, ntree_limit=gbm.best_ntree_limit),y_test)
# Out:
# 0.48280224902910446

# %% [markdown]
# To tune, we should use validation results and ignore test until final verification. So here's the validation error benchmark we want to beat:

# %%
rmse(gbm.predict(X_val, ntree_limit=gbm.best_ntree_limit),y_val)
# Out:
# 0.47920934718304553

# %% [markdown]
# ---
# **Xgboost Exercise**
#
# We'll approach tuning using this general framework, starting from the original parameters:
#
# 1. Tune max_depth
# 2. Tune subsample
# 3. Tune min_child_weight
# 4. Tune colsample_bytree
# 5. Set learning_rate to .05 and use early stopping to get n_estimators
#
# There are even more [xgboost parameters](https://github.com/dmlc/xgboost/blob/master/doc/parameter.md) such as regularization terms that are worth tuning, but this framework should be a starting point for solid parameters.
#
# For this process we'll repeat the cell block below with each adjustment and track our progress with comments, and tune in this way: say for max_depth, starting from 3 we try 5, 7 etc. until we stop improving then narrow down the search space.
#
# Start by _replacing the final parameters below_ with the basic parameters listed in the first run above, and see if you can recover parameters close to those referenced here.
#
# ---

# %%
#Step by step RMSEs, with .1 learning rate:
#best max_depth: 7, .452
#best subsample: .8, .448
#best min_child_weight: 12, .446
#best colsample_bytree: .7, .444

gbm = xgb.XGBRegressor(
    n_estimators=30000,  #arbitrary large number
    max_depth=7,
    objective="reg:linear",
    learning_rate=.05,
    subsample=.8,
    min_child_weight=8,
    colsample_bytree=.7,
    n_jobs=-1,
    random_state=0)

eval_set = [(X_train, y_train),
            (X_val, y_val)]  #tracking train/validation error as we go
fit_model = gbm.fit(
    X_train,
    y_train,
    eval_set=eval_set,
    eval_metric='rmse',
    early_stopping_rounds=50,
    verbose=False)
rmse(gbm.predict(X_val, ntree_limit=gbm.best_ntree_limit), y_val)
# Out:
# [10:52:16] WARNING: d:\build\xgboost\xgboost-0.90.git\src\objective\regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.4436113229603266

# %% [markdown]
# And our test MSE as a result of this process, a ~10% reduction in RMSE from the random forest model:

# %%
rmse(gbm.predict(X_test, ntree_limit=gbm.best_ntree_limit),y_test)
# Out:
# 0.45674836111575146

# %% [markdown]
# ---
#
# **Challenge**
#
# If you'd like to challenge yourself to get more proficient with xgboost, try tuning this model even more and beat our current score. Do some research into other xgboost parameters that you could try using. I'd recommend l1, l2, and gamma regularization terms.
#
# ---

# %% [markdown]
# **Interpretation**
#
# When trying to interpret a boosting model, we're faced with a similar challenge to that of interpreting a RF model. Many people would refer to it as a "black box" model. Luckily, there are some readily available ways to better understand feature importances and impacts on the model.
#
# The easiest method is very similar to RF feature importances. We can assign importance scores to features in a number of different ways, and xgboost lets us easily plot/extract these scores. The most common scoring methods are **frequency** (default, just calculates the # of total tree splits the feature is used in), and **gain** (probably better, calculates cumulative information gain from tree splits done on that feature).
#
# As we can see in the charts below, the two methods tend to agree on which features are most important. However, gain views Median Income as much more important than any of the other features, which seems like a reasonable conclusion.

# %%
xgb.plot_importance(gbm)
xgb.plot_importance(gbm, importance_type='gain')

# %%
gbm.get_booster().get_score(importance_type='weight') #extract raw frequency scores
# Out:
# {'AveRooms': 6938,
#  'Latitude': 7762,
#  'Population': 6254,
#  'HouseAge': 4474,
#  'AveBedrms': 6540,
#  'MedInc': 7549,
#  'Longitude': 7273,
#  'AveOccup': 7240}

# %%
gbm.get_booster().get_score(importance_type='gain') #extract raw gain scores
# Out:
# {'AveRooms': 1.7912579600825231,
#  'Latitude': 2.6841597641963326,
#  'Population': 0.5144919153003631,
#  'HouseAge': 1.505875546248292,
#  'AveBedrms': 0.8275592178033231,
#  'MedInc': 7.04121400103494,
#  'Longitude': 2.554145669856004,
#  'AveOccup': 2.1700779662018257}

# %% [markdown]
# A key problem with importance scores is that they only tell us which features are most relevant, not what the directional impact of the feature is on the model/target. Techniques have been developed to visually study these impacts that include [Partial Dependence](http://scikit-learn.org/stable/auto_examples/ensemble/plot_partial_dependence.html) and [Individual Conditional Expectation](https://arxiv.org/pdf/1309.6392.pdf) plots, but these are beyond the scope of this lecture.

# %% [markdown]
# **Classification Example**
#
# Breast cancer dataset (binary classification). Boosting does not seem to work that well on this problem (unsuprising given a small sample size of <600). But this shows how we can apply xgboost to a classification problem by simply changing the objective and eval_metric parameters.

# %%
bc_dataset = load_breast_cancer()
X = pd.DataFrame(bc_dataset.data)
X.columns = bc_dataset.feature_names
y = bc_dataset.target

#Split data into 3: 60% train, 20% validation, 20% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=2)

# %%
gbm = xgb.XGBClassifier( 
                        n_estimators=30000,
                        max_depth=4,
                        objective='binary:logistic', #new objective
                        learning_rate=.05, 
                        subsample=.8,
                        min_child_weight=3,
                        colsample_bytree=.8
                       )

eval_set=[(X_train,y_train),(X_val,y_val)]
fit_model = gbm.fit( 
                    X_train, y_train, 
                    eval_set=eval_set,
                    eval_metric='error', #new evaluation metric: classification error (could also use AUC, e.g.)
                    early_stopping_rounds=50,
                    verbose=False
                   )

accuracy_score(y_test, gbm.predict(X_test, ntree_limit=gbm.best_ntree_limit))
# Out:
# 0.956140350877193
